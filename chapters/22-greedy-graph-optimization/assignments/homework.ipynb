// %% [markdown]
// # Homework
//
// - Use these questions after class to check your understanding of the chapter concepts and coding skills.
// - Sign in from the account menu before you start working on the homework.
// - Complete all true/false and coding questions.

// %% [markdown]
// ## True or False
//
// **Question 1: Greedy choices**
//
// A greedy algorithm commits to a locally chosen option.
//
// - True
// - False

// %%
// Solution
// True.

// %% [markdown]
// **Question 2: Greedy correctness**
//
// Every greedy rule is automatically correct if it is easy to describe.
//
// - True
// - False

// %%
// Solution
// False. Greedy rules need correctness reasoning or counterexample testing.

// %% [markdown]
// **Question 3: MST**
//
// A minimum spanning tree connects all vertices in an undirected weighted graph without cycles.
//
// - True
// - False

// %%
// Solution
// True.

// %% [markdown]
// **Question 4: Dijkstra**
//
// Dijkstra's algorithm is designed for graphs with nonnegative edge weights.
//
// - True
// - False

// %%
// Solution
// True.

// %% [markdown]
// **Question 5: Problem choice**
//
// An MST and a shortest-path tree answer exactly the same question.
//
// - True
// - False

// %%
// Solution
// False. MST connects all vertices cheaply; shortest paths optimize routes from a source.

// %% [markdown]
// ## Coding Questions
//
// **Question 6: Meeting selection**
//
// Implement earliest-finish-time meeting selection.

// %%
using System;
using System.Linq;

// Your code starts here.


// Your code ends here.

// %% [markdown]
// **Question 7: Edge ordering**
//
// Create weighted edges and print them from cheapest to most expensive.

// %%
using System;
using System.Linq;

// Your code starts here.


// Your code ends here.

// %% [markdown]
// **Question 8: Detect a cycle candidate**
//
// Use component labels or parent pointers to decide whether an edge should be rejected.

// %%
using System;
using System.Collections.Generic;

// Your code starts here.


// Your code ends here.

// %% [markdown]
// **Question 9: Shortest distance update**
//
// Given a current distance and an edge cost, update a neighbor distance if the candidate is smaller.

// %%
using System;

int currentDistance = 6;
int edgeCost = 4;
int neighborDistance = 15;

// Your code starts here.


// Your code ends here.

// %% [markdown]
// **Question 10: Recommendation**
//
// Print a recommendation for MST or shortest path based on a scenario string.

// %%
using System;

string scenario = "find the cheapest route from HQ to every store";

// Your code starts here.


// Your code ends here.
