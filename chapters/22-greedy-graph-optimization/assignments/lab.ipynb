// %% [markdown]
// # Lab
//
// - Use this lab to practice greedy choices and graph optimization in runnable C# code.
// - Sign in from the account menu before you start working on the lab.
// - Launch Live Code (the rocket) to write and run code in the coding cells.

// %% [markdown]
// ## 1. Interval Scheduling
//
// Choose compatible meetings by earliest finish time.

// %%
using System;
using System.Linq;

// Your code starts here.


// Your code ends here.

// %% [markdown]
// ## 2. Greedy Counterexample
//
// Create a small example where choosing the largest immediate value is not best overall.

// %%
using System;

// Your code starts here.


// Your code ends here.

// %% [markdown]
// ## 3. Kruskal Step Trace
//
// Sort weighted edges by cost and print whether each edge is accepted or rejected.

// %%
using System;
using System.Linq;

// Your code starts here.


// Your code ends here.

// %% [markdown]
// ## 4. Dijkstra Distances
//
// Compute shortest distances from one source in a graph with nonnegative weights.

// %%
using System;
using System.Collections.Generic;

// Your code starts here.


// Your code ends here.

// %% [markdown]
// ## 5. Choose the Algorithm
//
// Given a short scenario, print whether it sounds like interval scheduling, MST, or shortest path.

// %%
using System;

string scenario = "connect all buildings with minimum cable";

// Your code starts here.


// Your code ends here.

// %% [markdown]
// ## Project Connection
//
// Name one project feature that could be modeled as a greedy choice, an MST, or a shortest-path problem. State the assumptions needed for the model to be valid.
