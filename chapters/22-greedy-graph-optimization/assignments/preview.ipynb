// %% [markdown]
// # Preview
//
// - Use these questions before class to check your familiarity with the chapter glossary and core terms.
// - Sign in from the account menu before you start answering the questions.
// - Multiple submissions are allowed if you want more practice.

// %% [markdown]
// ## Multiple Choice
//
// **1.** What does a greedy algorithm choose at each step?
//
// a) A locally best available option
// b) A random option
// c) Every possible option
// d) Only the final answer
//
// **2.** What does an invariant describe?
//
// a) A fact preserved after each step
// b) A missing namespace
// c) A file path
// d) A user-interface theme
//
// **3.** What does a minimum spanning tree connect?
//
// a) All vertices with no cycles and minimum total cost
// b) One source to one target only
// c) Only vertices with degree zero
// d) Only directed edges
//
// **4.** Dijkstra's algorithm requires which edge-weight condition?
//
// a) Nonnegative weights
// b) Negative weights only
// c) Equal weights only
// d) No weights at all
//
// **5.** Which problem asks for low-cost routes from a source?
//
// a) Shortest paths
// b) Minimum spanning tree only
// c) Bubble sort
// d) Interval formatting

// %% [markdown]
// ```{rubric} Footnotes
// ```
