// %% [markdown]
// # Greedy Algorithms and Graph Optimization
//
// This chapter studies algorithms that make locally best choices and graph problems where those choices can produce globally useful solutions.
//
// ```{tableofcontents}
// ```
