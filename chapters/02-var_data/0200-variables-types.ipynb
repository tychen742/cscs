# %% [markdown]
# # Variables & Types
#
# Programs store and transform data. This chapter introduces the fundamental building blocks of C#: naming values, choosing types, computing with expressions, and reading or displaying console data.
#
# - **Variables**: Names let programs store values and refer to them later.
# - **Types**: C# uses types such as `int`, `double`, `bool`, and `string` to define what each value can do.
# - **Operators**: Arithmetic, comparison, logical, and string operators let programs compute new values.
# - **Console I/O**: `Console.ReadLine` and `Console.WriteLine` connect a program to user input and output.
#
# These ideas are the raw materials for every later C# program: once you can name data, choose its type, transform it, and show a result, you can begin building useful workflows.

# %% [markdown]
# <h2>Chapter Video</h2>
#
# ```{eval-rst}
# .. youtube:: IxBMVztdlr4
#    :width: 560
#    :height: 315
# ```
#
# > *[C# variables ✖️](https://youtube.com/watch?v=IxBMVztdlr4)* by Bro Code.
# >
# > This video remains hosted on YouTube and is the property of its original creator or rightsholder; it is embedded here via YouTube's official player for educational reference only.

# %% [markdown]
# <h2>Learning Objectives</h2>
#
# By the end of this chapter, you will be able to:
# 1. Declare and initialize variables of numeric, Boolean, and string types
# 2. Choose appropriate C# types for common kinds of program data
# 3. Apply arithmetic, comparison, logical, and string operators correctly
# 4. Convert between compatible types using casts and parsing methods
# 5. Read console input and display formatted output

# %% [markdown]
# <h2>Chapter Flow</h2>
#
# ```{tableofcontents}
# ```

# %% [markdown]
# <h2>Glossary</h2>
#
# | # | Term | Explanation |
# |---:|---|---|
# | 1 | Variable | A named storage location whose value can be read and changed while a program runs. |
# | 2 | Type | A rule that tells C# what kind of value a variable can store and what operations are allowed. |
# | 3 | Declaration | A statement that introduces a variable name and its type. |
# | 4 | Initialization | Giving a variable its first value. |
# | 5 | Literal | A value written directly in source code, such as `42`, `true`, or `"hello"`. |
# | 6 | Integer type | A type that stores whole numbers without a fractional part. |
# | 7 | Floating-point type | A type that stores numbers with fractional values, such as `double` or `decimal`. |
# | 8 | Boolean | A type whose values are `true` or `false`. |
# | 9 | String | A sequence of characters stored as text. |
# | 10 | Expression | A piece of code that produces a value. |
# | 11 | Operator | A symbol or keyword that performs an operation on one or more values. |
# | 12 | Cast | An explicit conversion from one type to another. |
# | 13 | Parsing | Converting text input into a typed value. |
# | 14 | Console input | Data read from the terminal while a program runs. |
# | 15 | Formatted output | Output that combines text and values in a controlled layout. |
