# %% [markdown]
# # Variables & Types

# %% [markdown]
# <!-- chapter-intro -->
# This chapter introduces the core ideas of **Variables & Types** and prepares you for the sections that follow.

# %% [markdown]
# ```{tableofcontents}
# ```
