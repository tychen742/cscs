// %% [markdown]
// # Databases, Data Processing, and Persistent Information Systems
//
// This chapter connects C# objects and collections to data transformation, domain models, asynchronous I/O, and persistent relational data.
//
// ```{tableofcontents}
// ```
