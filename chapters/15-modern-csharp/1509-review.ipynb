// %% [markdown]
// # Chapter Review: Modern C#

// %% [markdown]
// ## Concept Questions
//
// 1. What four things does a positional `record` give you automatically?
// 2. What is the difference between a `record` and a `class` in terms of equality?
// 3. What does a `with` expression do? Does it modify the original?
// 4. What does `_` mean as a pattern arm in a `switch` expression?
// 5. What is the difference between `?.` and `??`? Can they be combined?
// 6. When would you use `record struct` instead of `record`?
// 7. What problem do generics solve? Why is `List<T>` better than `ArrayList`?
// 8. What does a `where T : IComparable<T>` constraint enforce, and why is it needed?
// 9. What does `await` do inside an `async` method? Does the calling thread block?
// 10. Why should you almost never write `async void` (except for event handlers)?

// %% [markdown]
// ## True / False
//
// 1. Two `record` instances with identical values are reference-equal (`object.ReferenceEquals`). ___
// 2. `with` creates a modified copy; the original record is unchanged. ___
// 3. Pattern matching in C# can test both type and value in the same arm. ___
// 4. `x?.Foo` throws a `NullReferenceException` if `x` is null. ___
// 5. `int?` can hold `null`; plain `int` cannot. ___
// 6. `record struct` is heap-allocated just like `record`. ___
// 7. A generic method `Max<T>` with no constraints can call `a.CompareTo(b)` on type parameter `T`. ___
// 8. `await` suspends the current method until the awaited `Task` completes, freeing the thread in the meantime. ___

// %% [markdown]
// ## Short Answer
//
// 1. What does this switch expression return for input `'e'`?
//    ```csharp
//    char c = 'e';
//    string kind = c switch {
//        'a' or 'e' or 'i' or 'o' or 'u' => "vowel",
//        >= 'a' and <= 'z'               => "consonant",
//        _                               => "other"
//    };
//    ```
// 2. Given `record Point(int X, int Y)`, write a one-liner that creates a copy of `p` with `X` set to `10`.
// 3. Rewrite safely: `if (a != null) return a.Name;` (using null-conditional and coalescing).
// 4. Write `string GradeLabel(int score)` as a switch expression using relational patterns.
// 5. Write the signature and implementation of a generic `static void Swap<T>(ref T a, ref T b)` method.
// 6. Convert `string text = File.ReadAllText(path)` to its async equivalent inside an `async Task` method.
