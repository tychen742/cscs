# %% [markdown]
# ```{index} loop; while while
# ```
#
# (while-loops)=
#
# # Iteration: While Loops
#
# ```{toctree}
# :maxdepth: 2
#
# 0601.while-statement
# 0602.while-examples
# 0603.do-while
# 0604.gcd-examples
# 0605.lab-while
# 0606.review-while
# ```
