# %% [markdown]
# ```{index} collections collections
# ```
#
# (collections)=
#
# # Collections
#
# ```{toctree}
# :maxdepth: 2
#
# 0901.collections
# 0902.list
# 0903.dictionary
# 0904.lab-collections
# 0905.review-collections
# ```
