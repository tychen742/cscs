// %% [markdown]
// # Homework
//
// - Use these questions after class to check your understanding of the chapter concepts and coding skills.
// - Sign in from the account menu before you start working on the homework.
// - Complete all true/false and coding questions before you submit the homework.
// - Launch Live Code (the rocket) to write and run code in the coding cells.
// - Multiple submissions are allowed. The highest score is kept.

// %% [markdown]
// ## True or False
//
// **Question 1: Tree roots**
//
// In a tree, the root is the starting node and has no parent.
//
// - True
// - False

// %%
// Solution
// True. The root is the top/start node of the tree.

// %% [markdown]
// **Question 2: Leaves**
//
// A leaf node is a node with no children.
//
// - True
// - False

// %%
// Solution
// True. Leaves are the endpoints of the tree.

// %% [markdown]
// **Question 3: BST search**
//
// When searching a BST, if the target is smaller than the current node's value, the search should move to the right subtree.
//
// - True
// - False

// %%
// Solution
// False. Smaller values belong in the left subtree.

// %% [markdown]
// **Question 4: Inorder traversal**
//
// For a valid BST with unique values, inorder traversal visits values in sorted order.
//
// - True
// - False

// %%
// Solution
// True. Inorder traversal follows left, node, right.

// %% [markdown]
// **Question 5: Tree shape**
//
// A simple BST built by inserting already sorted values can become a tall chain.
//
// - True
// - False

// %%
// Solution
// True. Without balancing, insertion order can create a poor shape.

// %% [markdown]
// ## Coding Practice

// %%
// 6. Count all nodes
// Complete Count so the program prints 5.

using System;

var root = new TreeNode(10);
root.Left = new TreeNode(5);
root.Right = new TreeNode(12);
root.Left.Left = new TreeNode(3);
root.Left.Right = new TreeNode(7);

Console.WriteLine(Count(root));

int Count(TreeNode? node)
{
    // Your code starts here.



    // Your code ends here.
}

class TreeNode
{
    public int Value { get; }
    public TreeNode? Left { get; set; }
    public TreeNode? Right { get; set; }
    public TreeNode(int value) => Value = value;
}

// %%
// Solution
using System;

var root = new TreeNode(10);
root.Left = new TreeNode(5);
root.Right = new TreeNode(12);
root.Left.Left = new TreeNode(3);
root.Left.Right = new TreeNode(7);

Console.WriteLine(Count(root));

int Count(TreeNode? node)
{
    if (node is null) return 0;
    return 1 + Count(node.Left) + Count(node.Right);
}

class TreeNode
{
    public int Value { get; }
    public TreeNode? Left { get; set; }
    public TreeNode? Right { get; set; }
    public TreeNode(int value) => Value = value;
}

// %%
// 7. Print preorder
// Complete Preorder so the root prints before its children.

using System;

var root = new TreeNode(10);
root.Left = new TreeNode(5);
root.Right = new TreeNode(12);

Preorder(root);
Console.WriteLine();

void Preorder(TreeNode? node)
{
    // Your code starts here.



    // Your code ends here.
}

class TreeNode
{
    public int Value { get; }
    public TreeNode? Left { get; set; }
    public TreeNode? Right { get; set; }
    public TreeNode(int value) => Value = value;
}

// %%
// Solution
using System;

var root = new TreeNode(10);
root.Left = new TreeNode(5);
root.Right = new TreeNode(12);

Preorder(root);
Console.WriteLine();

void Preorder(TreeNode? node)
{
    if (node is null) return;
    Console.Write(node.Value + " ");
    Preorder(node.Left);
    Preorder(node.Right);
}

class TreeNode
{
    public int Value { get; }
    public TreeNode? Left { get; set; }
    public TreeNode? Right { get; set; }
    public TreeNode(int value) => Value = value;
}

// %%
// 8. Find the minimum
// Complete Minimum by following left child references.

using System;

var root = new TreeNode(8);
root.Left = new TreeNode(3);
root.Right = new TreeNode(10);
root.Left.Left = new TreeNode(1);

Console.WriteLine(Minimum(root));

int Minimum(TreeNode node)
{
    // Your code starts here.



    // Your code ends here.
}

class TreeNode
{
    public int Value { get; }
    public TreeNode? Left { get; set; }
    public TreeNode? Right { get; set; }
    public TreeNode(int value) => Value = value;
}

// %%
// Solution
using System;

var root = new TreeNode(8);
root.Left = new TreeNode(3);
root.Right = new TreeNode(10);
root.Left.Left = new TreeNode(1);

Console.WriteLine(Minimum(root));

int Minimum(TreeNode node)
{
    TreeNode current = node;
    while (current.Left is not null)
    {
        current = current.Left;
    }

    return current.Value;
}

class TreeNode
{
    public int Value { get; }
    public TreeNode? Left { get; set; }
    public TreeNode? Right { get; set; }
    public TreeNode(int value) => Value = value;
}

// %%
// 9. Compute height
// Complete Height using the chapter convention: empty tree is -1.

using System;

var root = new TreeNode(8);
root.Left = new TreeNode(3);
root.Left.Left = new TreeNode(1);

Console.WriteLine(Height(root));

int Height(TreeNode? node)
{
    // Your code starts here.



    // Your code ends here.
}

class TreeNode
{
    public int Value { get; }
    public TreeNode? Left { get; set; }
    public TreeNode? Right { get; set; }
    public TreeNode(int value) => Value = value;
}

// %%
// Solution
using System;

var root = new TreeNode(8);
root.Left = new TreeNode(3);
root.Left.Left = new TreeNode(1);

Console.WriteLine(Height(root));

int Height(TreeNode? node)
{
    if (node is null) return -1;
    return 1 + Math.Max(Height(node.Left), Height(node.Right));
}

class TreeNode
{
    public int Value { get; }
    public TreeNode? Left { get; set; }
    public TreeNode? Right { get; set; }
    public TreeNode(int value) => Value = value;
}

// %%
// 10. Check sorted inorder result
// Insert the values into a BST and print its inorder traversal.

using System;
using System.Collections.Generic;

var tree = new BinarySearchTree();
foreach (int value in new[] { 5, 2, 8, 1, 3 })
{
    // Your code starts here.



    // Your code ends here.
}

Console.WriteLine(string.Join(", ", tree.InOrder()));

class BinarySearchTree
{
    private Node? root;
    public void Insert(int value) => root = Insert(root, value);

    public List<int> InOrder()
    {
        var values = new List<int>();
        InOrder(root, values);
        return values;
    }

    private static Node Insert(Node? node, int value)
    {
        if (node is null) return new Node(value);
        if (value < node.Value) node.Left = Insert(node.Left, value);
        else if (value > node.Value) node.Right = Insert(node.Right, value);
        return node;
    }

    private static void InOrder(Node? node, List<int> values)
    {
        if (node is null) return;
        InOrder(node.Left, values);
        values.Add(node.Value);
        InOrder(node.Right, values);
    }

    private sealed class Node
    {
        public int Value { get; }
        public Node? Left { get; set; }
        public Node? Right { get; set; }
        public Node(int value) => Value = value;
    }
}

// %%
// Solution
using System;
using System.Collections.Generic;

var tree = new BinarySearchTree();
foreach (int value in new[] { 5, 2, 8, 1, 3 })
{
    tree.Insert(value);
}

Console.WriteLine(string.Join(", ", tree.InOrder()));

class BinarySearchTree
{
    private Node? root;
    public void Insert(int value) => root = Insert(root, value);

    public List<int> InOrder()
    {
        var values = new List<int>();
        InOrder(root, values);
        return values;
    }

    private static Node Insert(Node? node, int value)
    {
        if (node is null) return new Node(value);
        if (value < node.Value) node.Left = Insert(node.Left, value);
        else if (value > node.Value) node.Right = Insert(node.Right, value);
        return node;
    }

    private static void InOrder(Node? node, List<int> values)
    {
        if (node is null) return;
        InOrder(node.Left, values);
        values.Add(node.Value);
        InOrder(node.Right, values);
    }

    private sealed class Node
    {
        public int Value { get; }
        public Node? Left { get; set; }
        public Node? Right { get; set; }
        public Node(int value) => Value = value;
    }
}

// %% [markdown]
// ## Submit
//
// Use the assignment submit panel when it is available in the published book.
