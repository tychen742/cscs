// %% [markdown]
// # Lab
//
// - Use this lab to practice the chapter's coding skills in runnable C# code.
// - Sign in from the account menu before you start working on the lab.
// - Launch Live Code (the rocket) to write and run code in the coding cells.
// - Multiple submissions are allowed. The highest score is kept.

// %% [markdown]
// ## 1. Build a Small Tree
//
// Attach left and right child nodes so the program prints `Root`, `Left`, and `Right`.

// %%
using System;

var root = new TreeNode("Root");

// Your code starts here.



// Your code ends here.

Console.WriteLine(root.Value);
Console.WriteLine(root.Left!.Value);
Console.WriteLine(root.Right!.Value);

class TreeNode
{
    public string Value { get; }
    public TreeNode? Left { get; set; }
    public TreeNode? Right { get; set; }
    public TreeNode(string value) => Value = value;
}

// %%
using System;

var root = new TreeNode("Root");
root.Left = new TreeNode("Left");
root.Right = new TreeNode("Right");

Console.WriteLine(root.Value);
Console.WriteLine(root.Left!.Value);
Console.WriteLine(root.Right!.Value);

class TreeNode
{
    public string Value { get; }
    public TreeNode? Left { get; set; }
    public TreeNode? Right { get; set; }
    public TreeNode(string value) => Value = value;
}

// %% [markdown]
// ## 2. Count Nodes
//
// Complete `Count` so it returns the number of nodes in the tree.

// %%
using System;

var root = new TreeNode(4);
root.Left = new TreeNode(2);
root.Right = new TreeNode(6);
root.Left.Left = new TreeNode(1);

Console.WriteLine(Count(root));

int Count(TreeNode? node)
{
    // Your code starts here.



    // Your code ends here.
}

class TreeNode
{
    public int Value { get; }
    public TreeNode? Left { get; set; }
    public TreeNode? Right { get; set; }
    public TreeNode(int value) => Value = value;
}

// %%
using System;

var root = new TreeNode(4);
root.Left = new TreeNode(2);
root.Right = new TreeNode(6);
root.Left.Left = new TreeNode(1);

Console.WriteLine(Count(root));

int Count(TreeNode? node)
{
    if (node is null) return 0;
    return 1 + Count(node.Left) + Count(node.Right);
}

class TreeNode
{
    public int Value { get; }
    public TreeNode? Left { get; set; }
    public TreeNode? Right { get; set; }
    public TreeNode(int value) => Value = value;
}

// %% [markdown]
// ## 3. Print Inorder
//
// Complete `InOrder` so the values print in sorted order for this BST.

// %%
using System;

var root = new TreeNode(4);
root.Left = new TreeNode(2);
root.Right = new TreeNode(6);
root.Left.Left = new TreeNode(1);
root.Left.Right = new TreeNode(3);

InOrder(root);
Console.WriteLine();

void InOrder(TreeNode? node)
{
    // Your code starts here.



    // Your code ends here.
}

class TreeNode
{
    public int Value { get; }
    public TreeNode? Left { get; set; }
    public TreeNode? Right { get; set; }
    public TreeNode(int value) => Value = value;
}

// %%
using System;

var root = new TreeNode(4);
root.Left = new TreeNode(2);
root.Right = new TreeNode(6);
root.Left.Left = new TreeNode(1);
root.Left.Right = new TreeNode(3);

InOrder(root);
Console.WriteLine();

void InOrder(TreeNode? node)
{
    if (node is null) return;
    InOrder(node.Left);
    Console.Write(node.Value + " ");
    InOrder(node.Right);
}

class TreeNode
{
    public int Value { get; }
    public TreeNode? Left { get; set; }
    public TreeNode? Right { get; set; }
    public TreeNode(int value) => Value = value;
}

// %% [markdown]
// ## 4. Search a BST
//
// Complete `Contains` so it follows the BST ordering rule.

// %%
using System;

var tree = new BinarySearchTree();
foreach (int value in new[] { 8, 3, 10, 1, 6 })
{
    tree.Insert(value);
}

Console.WriteLine(tree.Contains(6));
Console.WriteLine(tree.Contains(5));

class BinarySearchTree
{
    private Node? root;
    public void Insert(int value) => root = Insert(root, value);

    public bool Contains(int value)
    {
        Node? current = root;
        while (current is not null)
        {
            // Your code starts here.



            // Your code ends here.
        }

        return false;
    }

    private static Node Insert(Node? node, int value)
    {
        if (node is null) return new Node(value);
        if (value < node.Value) node.Left = Insert(node.Left, value);
        else if (value > node.Value) node.Right = Insert(node.Right, value);
        return node;
    }

    private sealed class Node
    {
        public int Value { get; }
        public Node? Left { get; set; }
        public Node? Right { get; set; }
        public Node(int value) => Value = value;
    }
}

// %%
using System;

var tree = new BinarySearchTree();
foreach (int value in new[] { 8, 3, 10, 1, 6 })
{
    tree.Insert(value);
}

Console.WriteLine(tree.Contains(6));
Console.WriteLine(tree.Contains(5));

class BinarySearchTree
{
    private Node? root;
    public void Insert(int value) => root = Insert(root, value);

    public bool Contains(int value)
    {
        Node? current = root;
        while (current is not null)
        {
            if (value == current.Value) return true;
            current = value < current.Value ? current.Left : current.Right;
        }

        return false;
    }

    private static Node Insert(Node? node, int value)
    {
        if (node is null) return new Node(value);
        if (value < node.Value) node.Left = Insert(node.Left, value);
        else if (value > node.Value) node.Right = Insert(node.Right, value);
        return node;
    }

    private sealed class Node
    {
        public int Value { get; }
        public Node? Left { get; set; }
        public Node? Right { get; set; }
        public Node(int value) => Value = value;
    }
}

// %% [markdown]
// ## 5. Compare Heights
//
// Build two trees from the two arrays and print each height.

// %%
using System;

int[] mixed = { 4, 2, 6, 1, 3 };
int[] sorted = { 1, 2, 3, 4, 6 };

// Your code starts here.



// Your code ends here.

class BinarySearchTree
{
    private Node? root;
    public void Insert(int value) => root = Insert(root, value);
    public int Height() => Height(root);

    private static Node Insert(Node? node, int value)
    {
        if (node is null) return new Node(value);
        if (value < node.Value) node.Left = Insert(node.Left, value);
        else if (value > node.Value) node.Right = Insert(node.Right, value);
        return node;
    }

    private static int Height(Node? node)
    {
        if (node is null) return -1;
        return 1 + Math.Max(Height(node.Left), Height(node.Right));
    }

    private sealed class Node
    {
        public int Value { get; }
        public Node? Left { get; set; }
        public Node? Right { get; set; }
        public Node(int value) => Value = value;
    }
}

// %%
using System;

int[] mixed = { 4, 2, 6, 1, 3 };
int[] sorted = { 1, 2, 3, 4, 6 };

var mixedTree = new BinarySearchTree();
foreach (int value in mixed)
{
    mixedTree.Insert(value);
}

var sortedTree = new BinarySearchTree();
foreach (int value in sorted)
{
    sortedTree.Insert(value);
}

Console.WriteLine(mixedTree.Height());
Console.WriteLine(sortedTree.Height());

class BinarySearchTree
{
    private Node? root;
    public void Insert(int value) => root = Insert(root, value);
    public int Height() => Height(root);

    private static Node Insert(Node? node, int value)
    {
        if (node is null) return new Node(value);
        if (value < node.Value) node.Left = Insert(node.Left, value);
        else if (value > node.Value) node.Right = Insert(node.Right, value);
        return node;
    }

    private static int Height(Node? node)
    {
        if (node is null) return -1;
        return 1 + Math.Max(Height(node.Left), Height(node.Right));
    }

    private sealed class Node
    {
        public int Value { get; }
        public Node? Left { get; set; }
        public Node? Right { get; set; }
        public Node(int value) => Value = value;
    }
}

// %% [markdown]
// ## Submit
//
// Use the assignment submit panel when it is available in the published book.
