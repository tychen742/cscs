// %% [markdown]
// # Trees
//
// This chapter covers general tree vocabulary, recursive tree structure, traversal orders, binary trees, binary search trees, and the way tree shape affects search and insertion cost. The sidebar title **Trees** keeps the navigation compact while the chapter body introduces binary search trees as the main ordered-tree example.
//
// - **Tree**: A tree organizes nodes into parent-child relationships with one root.
// - **Recursive structure**: Each child subtree can be treated as a smaller tree.
// - **Traversal**: Preorder, inorder, and postorder visit the same nodes in different orders.
// - **Binary search tree**: A BST stores smaller values to the left and larger values to the right.
// - **Shape and cost**: Tree height affects how many nodes search and insertion may inspect.
//
// Trees are the bridge from linear data structures to hierarchical and searchable structures. They also make recursion feel less artificial because the data itself is recursive.

// %% [markdown]
// <h2>Chapter Video</h2>
//
// ```{eval-rst}
// .. youtube:: J2fol8eWo64
//    :width: 560
//    :height: 315
// ```
//
// > *[Data Structures - Full Course for Beginners](https://youtube.com/watch?v=J2fol8eWo64)* by Tech With Tim.
// >
// > This video remains hosted on YouTube and is the property of its original creator or rightsholder; it is embedded here via YouTube's official player for educational reference only.

// %% [markdown]
// <h2>Learning Objectives</h2>
//
// By the end of this chapter, you will be able to:
// 1. Describe roots, parents, children, leaves, depth, height, and subtrees
// 2. Trace preorder, inorder, and postorder traversals
// 3. Represent a binary tree with node references in C#
// 4. Implement binary search tree search and insertion
// 5. Explain how tree shape affects the cost of search and insertion

// %% [markdown]
// <h2>Chapter Flow</h2>
//
// ```{tableofcontents}
// ```

// %% [markdown]
// <h2>Glossary</h2>
//
// | # | Term | Explanation |
// |---:|---|---|
// | 1 | Tree | A data structure made of nodes connected by parent-child relationships. |
// | 2 | Node | One stored item and its references to child nodes. |
// | 3 | Root | The top node of a tree, with no parent. |
// | 4 | Parent | A node that has a child beneath it. |
// | 5 | Child | A node directly below another node. |
// | 6 | Leaf | A node with no children. |
// | 7 | Edge | A connection between a parent and child node. |
// | 8 | Subtree | A node together with all nodes below it. |
// | 9 | Depth | The number of edges from the root to a node. |
// | 10 | Height | The longest downward path from a node to a leaf. |
// | 11 | Binary tree | A tree where each node has at most two children. |
// | 12 | Left child | The child reference conventionally drawn on the left. |
// | 13 | Right child | The child reference conventionally drawn on the right. |
// | 14 | Traversal | A rule for visiting every node in a tree. |
// | 15 | Preorder | Visit node, then left subtree, then right subtree. |
// | 16 | Inorder | Visit left subtree, then node, then right subtree. |
// | 17 | Postorder | Visit left subtree, then right subtree, then node. |
// | 18 | Binary search tree | A binary tree with an ordering rule that supports search. |
// | 19 | BST invariant | Values in the left subtree are smaller; values in the right subtree are larger. |
// | 20 | Balanced tree | A tree whose height stays small relative to its number of nodes. |

// %% [markdown]
// <h2><a href="overview.html" target="_blank" style="color: var(--pst-color-link, #176de8);">Chapter Overview Slides</a></h2>
