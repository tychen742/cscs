// %% [markdown]
// # Lab
//
// - Use this lab to practice the chapter's coding skills in runnable C# code.
// - Sign in from the account menu before you start working on the lab.
// - Launch Live Code (the rocket) to write and run code in the coding cells.
// - Multiple submissions are allowed. The highest score is kept.

// %% [markdown]
// ## 1. Process Priority Work
//
// Enqueue three tasks and print them in priority order. Lower numbers are more urgent.

// %%
using System;
using System.Collections.Generic;

var work = new PriorityQueue<string, int>();

// Your code starts here.



// Your code ends here.

// %%
using System;
using System.Collections.Generic;

var work = new PriorityQueue<string, int>();
work.Enqueue("Email update", 4);
work.Enqueue("Service outage", 0);
work.Enqueue("Password reset", 2);

while (work.Count > 0)
{
    Console.WriteLine(work.Dequeue());
}

// %% [markdown]
// ## 2. Map Keys to Buckets
//
// Print the bucket for each numeric key using `key % bucketCount`.

// %%
using System;

int[] keys = { 12, 19, 22, 31 };
int bucketCount = 5;

// Your code starts here.



// Your code ends here.

// %%
using System;

int[] keys = { 12, 19, 22, 31 };
int bucketCount = 5;

foreach (int key in keys)
{
    Console.WriteLine($"{key} -> {key % bucketCount}");
}

// %% [markdown]
// ## 3. Count Frequencies
//
// Use a dictionary to count each status string.

// %%
using System;
using System.Collections.Generic;

string[] statuses = { "open", "closed", "open", "waiting", "open" };
var counts = new Dictionary<string, int>();

// Your code starts here.



// Your code ends here.

// %%
using System;
using System.Collections.Generic;

string[] statuses = { "open", "closed", "open", "waiting", "open" };
var counts = new Dictionary<string, int>();

foreach (string status in statuses)
{
    if (!counts.ContainsKey(status)) counts[status] = 0;
    counts[status]++;
}

foreach (var pair in counts)
{
    Console.WriteLine($"{pair.Key}: {pair.Value}");
}

// %% [markdown]
// ## 4. Detect Duplicates
//
// Use a `HashSet<string>` to print only duplicate email addresses.

// %%
using System;
using System.Collections.Generic;

string[] emails = { "a@example.com", "b@example.com", "a@example.com", "c@example.com", "b@example.com" };
var seen = new HashSet<string>();

// Your code starts here.



// Your code ends here.

// %%
using System;
using System.Collections.Generic;

string[] emails = { "a@example.com", "b@example.com", "a@example.com", "c@example.com", "b@example.com" };
var seen = new HashSet<string>();

foreach (string email in emails)
{
    if (!seen.Add(email))
    {
        Console.WriteLine(email);
    }
}

// %% [markdown]
// ## 5. Keep the Two Highest Scores
//
// Use a min-priority queue with size two to keep the two highest scores.

// %%
using System;
using System.Collections.Generic;

int[] scores = { 70, 95, 82, 99, 88 };
var top = new PriorityQueue<int, int>();

// Your code starts here.



// Your code ends here.

// %%
using System;
using System.Collections.Generic;

int[] scores = { 70, 95, 82, 99, 88 };
var top = new PriorityQueue<int, int>();

foreach (int score in scores)
{
    top.Enqueue(score, score);
    if (top.Count > 2)
    {
        top.Dequeue();
    }
}

var result = new List<int>();
while (top.Count > 0)
{
    result.Add(top.Dequeue());
}
result.Sort();
result.Reverse();
Console.WriteLine(string.Join(", ", result));

// %% [markdown]
// ## Submit
//
// Use the assignment submit panel when it is available in the published book.
