// %% [markdown]
// # Homework
//
// - Use these questions after class to check your understanding of the chapter concepts and coding skills.
// - Sign in from the account menu before you start working on the homework.
// - Complete all true/false and coding questions before you submit the homework.
// - Launch Live Code (the rocket) to write and run code in the coding cells.
// - Multiple submissions are allowed. The highest score is kept.

// %% [markdown]
// ## True or False
//
// **Question 1: Priority scheduling**
//
// A priority queue is a good fit when the next item should be selected by urgency instead of arrival order.
//
// - True
// - False

// %%
// Solution
// True. Priority queues remove by priority.

// %% [markdown]
// **Question 2: Heap sorting**
//
// A valid heap must store every item in fully sorted array order.
//
// - True
// - False

// %%
// Solution
// False. A heap only enforces a parent-child priority rule, not full sorting.

// %% [markdown]
// **Question 3: Hash collisions**
//
// A collision means two different keys map to the same bucket.
//
// - True
// - False

// %%
// Solution
// True. Collision handling is a normal part of hash-table design.

// %% [markdown]
// **Question 4: Dictionary lookup**
//
// A dictionary is usually a better fit than a list when the main operation is looking up values by stable keys.
//
// - True
// - False

// %%
// Solution
// True. Dictionary<TKey, TValue> is designed for key-based lookup.

// %% [markdown]
// **Question 5: Sets**
//
// A `HashSet<T>` stores duplicate copies of the same value by default.
//
// - True
// - False

// %%
// Solution
// False. A set stores unique values.

// %% [markdown]
// ## Coding Practice

// %%
// 6. Process service tasks by priority
// Enqueue Backup, Outage, and Report with priorities 3, 0, and 5.
// Print tasks in priority order.

using System;
using System.Collections.Generic;

var queue = new PriorityQueue<string, int>();

// Your code starts here.



// Your code ends here.

// %%
// Solution
using System;
using System.Collections.Generic;

var queue = new PriorityQueue<string, int>();
queue.Enqueue("Backup", 3);
queue.Enqueue("Outage", 0);
queue.Enqueue("Report", 5);

while (queue.Count > 0)
{
    Console.WriteLine(queue.Dequeue());
}

// %%
// 7. Count categories
// Count each category with a dictionary.

using System;
using System.Collections.Generic;

string[] categories = { "bug", "task", "bug", "feature" };
var counts = new Dictionary<string, int>();

// Your code starts here.



// Your code ends here.

// %%
// Solution
using System;
using System.Collections.Generic;

string[] categories = { "bug", "task", "bug", "feature" };
var counts = new Dictionary<string, int>();

foreach (string category in categories)
{
    if (!counts.ContainsKey(category)) counts[category] = 0;
    counts[category]++;
}

foreach (var pair in counts)
{
    Console.WriteLine($"{pair.Key}: {pair.Value}");
}

// %%
// 8. Use a set for membership
// Add completed ticket IDs to a HashSet and test whether T-2 is complete.

using System;
using System.Collections.Generic;

var completed = new HashSet<string>();

// Your code starts here.



// Your code ends here.

// %%
// Solution
using System;
using System.Collections.Generic;

var completed = new HashSet<string>();
completed.Add("T-1");
completed.Add("T-2");
completed.Add("T-3");

Console.WriteLine(completed.Contains("T-2"));

// %%
// 9. Compute load factor
// Print the load factor for 12 items in 20 buckets.

using System;

int itemCount = 12;
int bucketCount = 20;

// Your code starts here.



// Your code ends here.

// %%
// Solution
using System;

int itemCount = 12;
int bucketCount = 20;
double loadFactor = (double)itemCount / bucketCount;

Console.WriteLine($"{loadFactor:0.00}");

// %%
// 10. Bucket mapping
// Print the bucket for each key using key % 4.

using System;

int[] keys = { 4, 7, 9, 12 };

// Your code starts here.



// Your code ends here.

// %%
// Solution
using System;

int[] keys = { 4, 7, 9, 12 };

foreach (int key in keys)
{
    Console.WriteLine($"{key}: {key % 4}");
}

// %% [markdown]
// ## Submit
//
// Use the assignment submit panel when it is available in the published book.
