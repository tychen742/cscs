// %% [markdown]
// # Recurrences and Recursive Cost
//
// Recursive algorithms solve a problem by solving smaller versions of the same problem. Recurrence relations describe how their work grows, preparing us to analyze divide-and-conquer algorithms in Chapter 20.
