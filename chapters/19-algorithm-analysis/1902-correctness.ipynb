// %% [markdown]
// # Correctness and Invariants
//
// An algorithm is useful only when it produces the required result. Learn to state a precondition, postcondition, and loop invariant, then use them to explain why an algorithm works.
