// %% [markdown]
// # Homework
//
// - Use these questions after class to check your understanding of the chapter concepts and coding skills.
// - Sign in from the account menu before you start working on the homework.
// - Complete all true/false and coding questions.

// %% [markdown]
// ## True or False
//
// **Question 1: Exact runtime**
//
// Big-O notation gives the exact runtime of a program on every computer.
//
// - True
// - False

// %%
// Solution
// False. Big-O describes asymptotic growth, not exact runtime.

// %% [markdown]
// **Question 2: Linear loops**
//
// A loop that visits each of `n` items once is usually `O(n)`.
//
// - True
// - False

// %%
// Solution
// True.

// %% [markdown]
// **Question 3: Preconditions**
//
// A precondition describes something that should be true before an algorithm runs.
//
// - True
// - False

// %%
// Solution
// True.

// %% [markdown]
// **Question 4: Invariants**
//
// A loop invariant may be false before the loop starts as long as it is true at the end.
//
// - True
// - False

// %%
// Solution
// False. A loop invariant should be true before the loop starts and preserved by each iteration.

// %% [markdown]
// **Question 5: Recurrences**
//
// A recurrence can describe the cost of a recursive algorithm.
//
// - True
// - False

// %%
// Solution
// True.

// %% [markdown]
// ## Coding Questions
//
// **Question 6: Count operations**
//
// Write a loop that sums an array and counts how many additions it performs.

// %%
using System;

int[] values = { 1, 2, 3, 4, 5 };

// Your code starts here.


// Your code ends here.

// %% [markdown]
// **Question 7: Compare growth counts**
//
// For `n = 10`, print the counts for `n`, `n * n`, and `n * Math.Log2(n)`.

// %%
using System;

int n = 10;

// Your code starts here.


// Your code ends here.

// %% [markdown]
// **Question 8: Guard a method**
//
// Write a method that returns the first item in an array. Throw an `ArgumentException` if the array is empty.

// %%
using System;

int[] values = { 42, 7, 9 };

// Your code starts here.


// Your code ends here.

// %% [markdown]
// **Question 9: Trace a search invariant**
//
// Search an array for a target value and print each index as it is checked. Add a comment that states what is known before each check.

// %%
using System;

int[] values = { 5, 8, 11, 14 };
int target = 11;

// Your code starts here.


// Your code ends here.

// %% [markdown]
// **Question 10: Recursive cost**
//
// Write a recursive method that returns the depth of repeatedly subtracting one from `n` until zero. Print the result for `n = 5` and name the growth rate in a comment.

// %%
using System;

int n = 5;

// Your code starts here.


// Your code ends here.
