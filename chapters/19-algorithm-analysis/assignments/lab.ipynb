// %% [markdown]
// # Lab
//
// - Use this lab to practice the chapter's analysis skills in runnable C# code.
// - Sign in from the account menu before you start working on the lab.
// - Launch Live Code (the rocket) to write and run code in the coding cells.

// %% [markdown]
// ## 1. Count a Linear Loop
//
// Write a loop over an array and count how many times the loop body runs. Print the count and describe the growth rate in a comment.

// %%
using System;

int[] values = { 2, 4, 6, 8, 10 };
int operations = 0;

// Your code starts here.


// Your code ends here.

// %% [markdown]
// ## 2. Count Nested Loops
//
// Write nested loops over the same array and count the total number of pairs considered.

// %%
using System;

int[] values = { 2, 4, 6, 8, 10 };
int pairs = 0;

// Your code starts here.


// Your code ends here.

// %% [markdown]
// ## 3. Check a Precondition
//
// Write a function named `RequireNonEmpty` that throws an exception when an array is empty. Call it before computing an average.

// %%
using System;
using System.Linq;

int[] values = { 10, 20, 30 };

// Your code starts here.


// Your code ends here.

// %% [markdown]
// ## 4. State and Trace an Invariant
//
// Trace a maximum-finding loop by printing the current `best` value after each iteration. Add a comment that states the loop invariant.

// %%
using System;

int[] values = { 3, 1, 9, 2 };
int best = values[0];

// Your code starts here.


// Your code ends here.

// %% [markdown]
// ## 5. Estimate Recursive Levels
//
// Write a recursive function that counts how many times an input can be divided by two before it reaches `1`.

// %%
using System;

int n = 64;

// Your code starts here.


// Your code ends here.

// %% [markdown]
// ## Project Connection
//
// Choose one operation from your course project and classify its expected growth rate. If the project stores data in a list, dictionary, tree, or graph, explain which operation you expect to dominate runtime.
