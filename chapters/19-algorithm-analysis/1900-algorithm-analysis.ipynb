// %% [markdown]
// # Algorithm Analysis
//
// An algorithm is a precise procedure for solving a problem. Algorithm analysis asks two questions:
//
// 1. Does the procedure produce the required result?
// 2. How do its time and memory needs grow as the input grows?
//
// This chapter introduces correctness, asymptotic analysis, Big-O notation, and recurrences. Later chapters use these tools to compare searching, sorting, graph, and optimization algorithms.

// %% [markdown]
// <h2>Why this chapter matters</h2>
//
// Knowing an algorithm's behavior under different inputs separates guessing from engineering:
//
// - linear search is simple but slow for large sorted data
// - binary search cuts the problem in half with every comparison
// - sorting algorithms trade simplicity for speed depending on input size
// - Big-O notation gives a hardware-independent language for comparing algorithms

// %% [markdown]
// <h2>Learning goals</h2>
//
// By the end of this chapter, you should be able to:
//
// - implement and compare linear and binary search
// - trace through bubble, selection, and insertion sort
// - explain what O(N), O(N log N), and O(N²) mean
// - measure and interpret actual runtime performance

// %% [markdown]
// <h2>Intro video</h2>
//
// ```{eval-rst}
// .. youtube:: IcDcNp8gZ7U
//    :width: 560
//    :height: 315
// ```
//
// > *[Data Structures and Algorithms In C#: Big-O Notation](https://youtube.com/watch?v=IcDcNp8gZ7U)* by Teddy Smith.
// >
// > This video remains hosted on YouTube and is the property of its original creator or rightsholder; it is embedded here via YouTube's official player for educational reference only.

// %% [markdown]
// <h2>Chapter flow</h2>
//
// ```{tableofcontents}
// ```
