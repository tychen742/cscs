# %% [markdown]
# ```{index} file
# ```
#
# (files)=
#
# # Files and Text
#
# Most useful programs eventually read data from outside the program or write results somewhere durable. This chapter introduces file operations and text processing so you can work with multi-line content and structured records.
#
# - **File I/O**: File input and output let a program read stored data and save results.
# - **Streams**: Streams provide a sequence-oriented way to read from or write to a source.
# - **Text processing**: Trimming, casing, splitting, and replacing help clean and transform text.
# - **Structured records**: Delimited text such as CSV stores fields that must be parsed and validated.
# - **Regular expressions**: Regex patterns describe text shapes for search, validation, and extraction.
#
# Reliable text handling turns raw files, exports, logs, and user-entered records into data a program can actually use.

# %% [markdown]
# <h2>Chapter Video</h2>
#
# ```{eval-rst}
# .. youtube:: tApBDuVwCrc
#    :width: 560
#    :height: 315
# ```
#
# > *[Read and Write files in 10 minutes | C#](https://youtube.com/watch?v=tApBDuVwCrc)* by tutorialsEU.
# >
# > This video remains hosted on YouTube and is the property of its original creator or rightsholder; it is embedded here via YouTube's official player for educational reference only.

# %% [markdown]
# <h2>Learning Objectives</h2>
#
# By the end of this chapter, you will be able to:
# 1. Read text from files and write text output safely
# 2. Clean text with trimming, casing, splitting, and replacement methods
# 3. Parse structured text lines into typed values
# 4. Validate fields before using parsed data
# 5. Use regular expressions for targeted text search and matching

# %% [markdown]
# <h2>Chapter Flow</h2>
#
# ```{tableofcontents}
# ```

# %% [markdown]
# <h2>Glossary</h2>
#
# | # | Term | Explanation |
# |---:|---|---|
# | 1 | File | Named data stored outside a running program. |
# | 2 | Path | A string that identifies a file or folder location. |
# | 3 | Stream | A flow of data read from or written to a source. |
# | 4 | Text file | A file whose contents are characters organized as lines. |
# | 5 | Read | Load data from a file into a program. |
# | 6 | Write | Save data from a program into a file. |
# | 7 | Append | Add new data to the end of an existing file. |
# | 8 | Line | A sequence of text ending at a line break. |
# | 9 | Parse | Convert text into structured or typed values. |
# | 10 | Delimiter | A character used to separate fields in text data. |
# | 11 | Trim | Remove extra whitespace from the beginning or end of text. |
# | 12 | Split | Break a string into parts. |
# | 13 | Regular expression | A pattern language for matching text. |
# | 14 | Match | A piece of text that satisfies a search pattern. |
