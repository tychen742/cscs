// %% [markdown]
// # Selected Topics
//
// This chapter covers advanced C# features not found in earlier chapters.
// Each section is self-contained — read in any order.
//
// | Section | Topic |
// |---------|-------|
// | Recursion | Methods that call themselves |
// | Lambda Expressions | Inline anonymous functions |
// | LINQ | Query and transform collections |
// | Pattern Matching | Expressive `switch` and `is` expressions |
// | Tuples | Lightweight multi-value types |
