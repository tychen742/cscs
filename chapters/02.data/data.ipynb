# %% [markdown]
# # Data and Variables
#
# ```{toctree}
# :maxdepth: 2
#
# 0201.data_types
# 0202.variables
# 0203.operators
# 0204.arithmetic
# 0205.strings
# 0206.input_output
# 0207.lab02
# 0208.review
# ```
