// %% [markdown]
// # Homework
//
// - Use these questions after class to check your understanding of the chapter concepts and coding skills.
// - Sign in from the account menu before you start working on the homework.
// - Complete all true/false and coding questions.

// %% [markdown]
// ## True or False
//
// **Question 1: Vertices**
//
// A vertex is one item or node in a graph.
//
// - True
// - False

// %%
// Solution
// True.

// %% [markdown]
// **Question 2: Directed edges**
//
// If a graph is directed, an edge from A to B automatically means there is also an edge from B to A.
//
// - True
// - False

// %%
// Solution
// False. Directed edges have a one-way direction unless the reverse edge is also stored.

// %% [markdown]
// **Question 3: Matrix space**
//
// An adjacency matrix stores space for every possible pair of vertices.
//
// - True
// - False

// %%
// Solution
// True.

// %% [markdown]
// **Question 4: Sparse graphs**
//
// Adjacency lists are often a good fit for sparse graphs.
//
// - True
// - False

// %%
// Solution
// True.

// %% [markdown]
// **Question 5: Weights**
//
// A weighted edge can store values such as cost, distance, or time.
//
// - True
// - False

// %%
// Solution
// True.

// %% [markdown]
// ## Coding Questions
//
// **Question 6: Print an edge list**
//
// Create a list of directed edges for three web pages and print each link as `from -> to`.

// %%
using System;

// Your code starts here.


// Your code ends here.

// %% [markdown]
// **Question 7: Build an undirected graph**
//
// Use a dictionary of lists to store four people and at least four friendship edges. Print every person with their friends.

// %%
using System;
using System.Collections.Generic;

// Your code starts here.


// Your code ends here.

// %% [markdown]
// **Question 8: Count degree**
//
// Write a function that returns the degree of a vertex in an undirected adjacency-list graph.

// %%
using System;
using System.Collections.Generic;

var graph = new Dictionary<string, List<string>>
{
    ["A"] = new() { "B", "C" },
    ["B"] = new() { "A" },
    ["C"] = new() { "A", "D" },
    ["D"] = new() { "C" }
};

// Your code starts here.


// Your code ends here.

// %% [markdown]
// **Question 9: Create a weighted matrix**
//
// Create a weighted adjacency matrix for three cities. Store two undirected routes and print one direct route lookup.

// %%
using System;
using System.Collections.Generic;

// Your code starts here.


// Your code ends here.

// %% [markdown]
// **Question 10: Representation choice**
//
// Given 50 vertices and 60 undirected edges, compute the density and print whether you would begin with an adjacency list or matrix.

// %%
using System;

// Your code starts here.


// Your code ends here.
