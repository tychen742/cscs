// %% [markdown]
// # Preview
//
// - Use these questions before class to check your familiarity with the chapter glossary and core terms.
// - Sign in from the account menu before you start answering the questions.
// - Multiple submissions are allowed if you want more practice.

// %% [markdown]
// ## Multiple Choice
//
// **1.** What is a vertex in a graph?
//
// a) A loop condition
// b) One item or node in the graph
// c) A sorted array index
// d) A method parameter
//
// **2.** What does an edge represent?
//
// a) A relationship between vertices
// b) The last item in a queue
// c) A class constructor
// d) A nullable value
//
// **3.** Which representation uses a two-dimensional table?
//
// a) Stack
// b) Queue
// c) Adjacency matrix
// d) Linked list
//
// **4.** Which representation usually fits sparse graphs well?
//
// a) Adjacency list
// b) Full matrix only
// c) Sorted string
// d) Single integer counter
//
// **5.** What does a weighted edge store?
//
// a) A value such as distance, cost, or time
// b) Only a boolean loop guard
// c) A namespace import
// d) The number of source files

// %% [markdown]
// ```{rubric} Footnotes
// ```
