// %% [markdown]
// # Lab
//
// - Use this lab to practice the chapter's coding skills in runnable C# code.
// - Sign in from the account menu before you start working on the lab.
// - Launch Live Code (the rocket) to write and run code in the coding cells.

// %% [markdown]
// ## 1. Create Vertices and Edges
//
// Create an array of five room names and an array of four undirected edges connecting them. Print each edge.

// %%
using System;

// Your code starts here.


// Your code ends here.

// %% [markdown]
// ## 2. Build an Adjacency List
//
// Use a `Dictionary<string, List<string>>` to store the room graph from Question 1. Add both directions for each undirected edge.

// %%
using System;
using System.Collections.Generic;

var graph = new Dictionary<string, List<string>>();

// Your code starts here.


// Your code ends here.

// %% [markdown]
// ## 3. Print Degrees
//
// Loop through the adjacency list and print each room's degree.

// %%
using System;
using System.Collections.Generic;

var graph = new Dictionary<string, List<string>>
{
    ["Lobby"] = new() { "Hall" },
    ["Hall"] = new() { "Lobby", "Lab", "Office" },
    ["Lab"] = new() { "Hall" },
    ["Office"] = new() { "Hall", "Storage" },
    ["Storage"] = new() { "Office" }
};

// Your code starts here.


// Your code ends here.

// %% [markdown]
// ## 4. Check Direct Connections
//
// Write a helper function named `HasEdge` that returns whether two rooms are directly connected.

// %%
using System;
using System.Collections.Generic;
using System.Linq;

var graph = new Dictionary<string, List<string>>
{
    ["Lobby"] = new() { "Hall" },
    ["Hall"] = new() { "Lobby", "Lab", "Office" },
    ["Lab"] = new() { "Hall" },
    ["Office"] = new() { "Hall", "Storage" },
    ["Storage"] = new() { "Office" }
};

// Your code starts here.


// Your code ends here.

// %% [markdown]
// ## 5. Add Weights
//
// Convert the graph to store walking minutes with each neighbor, then print the neighbors of `Hall` with their weights.

// %%
using System;
using System.Collections.Generic;

var weightedGraph = new Dictionary<string, List<(string Neighbor, int Minutes)>>();

// Your code starts here.


// Your code ends here.

// %% [markdown]
// ## Project Connection
//
// For your course project, identify one part of your domain that can be modeled as a graph. Write down the vertices, the edges, whether edges are directed, and whether weights are useful.
