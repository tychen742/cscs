// %% [markdown]
// # Lab
//
// - Use this lab to practice recursion and divide-and-conquer in runnable C# code.
// - Sign in from the account menu before you start working on the lab.
// - Launch Live Code (the rocket) to write and run code in the coding cells.

// %% [markdown]
// ## 1. Recursive Sum
//
// Write a recursive method named `SumDown` that returns `n + (n - 1) + ... + 1`. Use `0` as the base case.

// %%
using System;

int n = 5;

// Your code starts here.


// Your code ends here.

// %% [markdown]
// ## 2. Trace Factorial
//
// Write a recursive factorial method that prints when each call starts and when each call returns.

// %%
using System;

int n = 4;

// Your code starts here.


// Your code ends here.

// %% [markdown]
// ## 3. Recursive Search
//
// Write a recursive method named `Contains` that searches an array from a given index.

// %%
using System;

int[] values = { 4, 8, 15, 16, 23, 42 };
int target = 15;

// Your code starts here.


// Your code ends here.

// %% [markdown]
// ## 4. Merge Two Sorted Arrays
//
// Write a `Merge` method that combines two sorted arrays into one sorted array.

// %%
using System;

int[] left = { 1, 4, 9 };
int[] right = { 2, 5, 8 };

// Your code starts here.


// Your code ends here.

// %% [markdown]
// ## 5. Complete Merge Sort
//
// Use your merge method to implement recursive merge sort. Print the sorted result.

// %%
using System;

int[] values = { 7, 3, 9, 1, 5 };

// Your code starts here.


// Your code ends here.

// %% [markdown]
// ## Project Connection
//
// Identify one project feature that can be described recursively or with divide-and-conquer. If none fits naturally, explain why iteration is a better choice for that feature.
