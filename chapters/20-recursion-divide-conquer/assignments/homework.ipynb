// %% [markdown]
// # Homework
//
// - Use these questions after class to check your understanding of the chapter concepts and coding skills.
// - Sign in from the account menu before you start working on the homework.
// - Complete all true/false and coding questions.

// %% [markdown]
// ## True or False
//
// **Question 1: Base cases**
//
// Every recursive method needs a base case or it may call itself forever.
//
// - True
// - False

// %%
// Solution
// True.

// %% [markdown]
// **Question 2: Progress**
//
// A recursive call should move closer to a base case.
//
// - True
// - False

// %%
// Solution
// True.

// %% [markdown]
// **Question 3: Call stack**
//
// Recursive calls use the call stack.
//
// - True
// - False

// %%
// Solution
// True.

// %% [markdown]
// **Question 4: Divide-and-conquer**
//
// A divide-and-conquer algorithm always solves exactly one subproblem.
//
// - True
// - False

// %%
// Solution
// False. Some solve one subproblem, but many solve two or more.

// %% [markdown]
// **Question 5: Merge sort**
//
// Merge sort combines sorted halves using a merge operation.
//
// - True
// - False

// %%
// Solution
// True.

// %% [markdown]
// ## Coding Questions
//
// **Question 6: Count recursively**
//
// Write a recursive method that returns how many integers are in the range from `n` down to `1`.

// %%
using System;

int n = 6;

// Your code starts here.


// Your code ends here.

// %% [markdown]
// **Question 7: Recursive array sum**
//
// Write a recursive method that sums an array starting at a given index.

// %%
using System;

int[] values = { 3, 5, 7, 9 };

// Your code starts here.


// Your code ends here.

// %% [markdown]
// **Question 8: Binary search**
//
// Write a recursive binary search method that returns the index of a target or `-1` if the target is missing.

// %%
using System;

int[] values = { 2, 4, 6, 8, 10, 12 };
int target = 8;

// Your code starts here.


// Your code ends here.

// %% [markdown]
// **Question 9: Merge helper**
//
// Write a method that merges two sorted arrays and prints the merged result.

// %%
using System;

int[] left = { 1, 3, 7 };
int[] right = { 2, 4, 6 };

// Your code starts here.


// Your code ends here.

// %% [markdown]
// **Question 10: Trace recursive depth**
//
// Write a recursive method that returns how many times `n` can be divided by two before reaching `1` or less. Print the result for `n = 32`.

// %%
using System;

int n = 32;

// Your code starts here.


// Your code ends here.
