// %% [markdown]
// # Preview
//
// - Use these questions before class to check your familiarity with the chapter glossary and core terms.
// - Sign in from the account menu before you start answering the questions.
// - Multiple submissions are allowed if you want more practice.

// %% [markdown]
// ## Multiple Choice
//
// **1.** What is the purpose of a base case?
//
// a) It stops recursion with a direct answer
// b) It imports a namespace
// c) It makes every loop quadratic
// d) It stores all program files
//
// **2.** What should happen to the progress measure in each recursive call?
//
// a) It should move closer to the base case
// b) It should stay exactly the same
// c) It should become a string
// d) It should be ignored
//
// **3.** What does the call stack track?
//
// a) Active method calls and their local state
// b) Git branches
// c) The number of folders in a project
// d) All installed packages
//
// **4.** Which phrase best describes divide-and-conquer?
//
// a) Split, solve, and combine
// b) Print, pause, and delete
// c) Sort only with nested loops
// d) Store every value in a queue
//
// **5.** What does merge do in merge sort?
//
// a) Combines two sorted sequences into one sorted sequence
// b) Deletes duplicate source files
// c) Converts strings to integers
// d) Checks whether recursion is allowed

// %% [markdown]
// ```{rubric} Footnotes
// ```
