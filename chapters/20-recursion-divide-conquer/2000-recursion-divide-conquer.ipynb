// %% [markdown]
// # Recursion and Divide-and-Conquer
//
// Recursion solves a problem by calling the same method on a smaller version of that problem. Divide-and-conquer uses the same idea at the algorithm-design level: split the input, solve smaller parts, and combine the answers.
//
// - **Base case**: The condition that stops recursion with a direct answer.
// - **Recursive case**: The part of the method that calls itself on a smaller input.
// - **Progress measure**: A quantity that moves toward the base case on every recursive call.
// - **Call stack**: The runtime structure that tracks active method calls and their local variables.
// - **Divide-and-conquer**: A design pattern that divides a problem, solves subproblems, and combines results.

// %% [markdown]
// <h2>Learning Objectives</h2>
//
// By the end of this chapter, you will be able to:
//
// 1. Identify base cases, recursive cases, and progress measures in recursive C# methods.
// 2. Trace recursive calls using a call-stack model.
// 3. Rewrite simple loop-shaped problems recursively when recursion clarifies the structure.
// 4. Apply divide-and-conquer thinking to halving, searching, and sorting problems.
// 5. Implement and test merge operations and merge sort.

// %% [markdown]
// <h2>Chapter Flow</h2>
//
// ```{tableofcontents}
// ```

// %% [markdown]
// <h2>Glossary</h2>
//
// ```{glossary}
// Recursion
//   A technique where a method solves a problem by calling itself on a smaller input.
//
// Base case
//   A directly solved case that stops recursive calls.
//
// Recursive case
//   The branch that makes one or more recursive calls.
//
// Progress measure
//   A value, such as `n` or a range length, that gets closer to the base case with each call.
//
// Call stack
//   The runtime stack of active method calls.
//
// Divide-and-conquer
//   An algorithm design pattern that splits a problem into subproblems, solves them, and combines the answers.
//
// Merge
//   The process of combining two sorted sequences into one sorted sequence.
//
// Merge sort
//   A divide-and-conquer sorting algorithm that recursively sorts halves and merges them.
// ```

// %% [markdown]
// <h2>Slides</h2>
//
// Slides for this chapter will be added after the notebook content stabilizes.
