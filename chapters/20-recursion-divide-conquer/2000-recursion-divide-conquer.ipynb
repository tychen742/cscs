// %% [markdown]
// # Recursion and Divide-and-Conquer
//
// This chapter studies recursive problem solving and algorithms that divide a problem into smaller subproblems.
//
// ```{tableofcontents}
// ```
