// %% [markdown]
// # Divide-and-Conquer Design
//
// Divide-and-conquer algorithms split a problem, solve the smaller problems, and combine their results. Analyze the work at each level and the resulting recurrence.
