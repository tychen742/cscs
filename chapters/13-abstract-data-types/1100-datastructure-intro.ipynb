// %% [markdown]
// ```{index} abstract data type; data structure interface
// ```
//
// (abstract-data-types)=
//
// # Abstract Data Types, Interfaces, and Generics
//
// <!-- chapter-intro -->
//
// An **abstract data type** describes the values and operations a program needs without requiring one particular representation. This chapter connects interfaces, references, memory models, and generic code to the data structures used throughout the later chapters.

// %% [markdown]
// <h2>Why this chapter matters</h2>
//
// The same data can be organized in many ways, each with different trade-offs:
//
// - sequential vs. key-based access patterns
// - insertion, deletion, and lookup costs vary by structure
// - stacks and queues model natural real-world orderings
// - understanding internals helps you reason about performance

// %% [markdown]
// <h2>Learning goals</h2>
//
// By the end of this chapter, you should be able to:
//
// - compare the trade-offs of array, list, and dictionary in concrete scenarios
// - explain how a stack (LIFO) and queue (FIFO) differ
// - select an appropriate collection type for a given problem
// - trace through examples involving nested or composed data structures

// %% [markdown]
// <h2>Intro video</h2>
//
// ```{eval-rst}
// .. youtube:: G0bD3Af1DRc
//    :width: 560
//    :height: 315
// ```
//
// > *[C# Data Structures - Arrays, Lists, Dictionaries, HashSets, Stacks, Queues](https://youtube.com/watch?v=G0bD3Af1DRc)* by Mark Inman.
// >
// > This video remains hosted on YouTube and is the property of its original creator or rightsholder; it is embedded here via YouTube's official player for educational reference only.

// %% [markdown]
// <h2>Chapter flow</h2>
//
// ```{tableofcontents}
// ```
