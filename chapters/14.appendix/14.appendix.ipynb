# %% [markdown]
# (appendix)=
#
# # Appendix
#
# ```{toctree}
# :maxdepth: 2
#
# 1401.resources
# 1402.command-line
# 1403.precedence
# 1404.acknowledgments
# homework-gradecalculation
# homework-gradecalculation2
# hw-gradefiles
# hw-booklist
# project
# lab-versioncontrol
# hgteamwork
# ```
#
# % out of date
# % offerings
