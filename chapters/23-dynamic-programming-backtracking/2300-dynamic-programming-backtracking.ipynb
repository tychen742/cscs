// %% [markdown]
// # Dynamic Programming and Backtracking
//
// This chapter studies problems with overlapping subproblems and problems that require systematic search with pruning.
//
// ```{tableofcontents}
// ```
