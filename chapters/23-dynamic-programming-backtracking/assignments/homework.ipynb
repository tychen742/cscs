// %% [markdown]
// # Homework
//
// - Use these questions after class to check your understanding of the chapter concepts and coding skills.
// - Sign in from the account menu before you start working on the homework.
// - Complete all true/false and coding questions.

// %% [markdown]
// ## True or False
//
// **Question 1: Overlap**
//
// Dynamic programming is useful when subproblems overlap.
//
// - True
// - False

// %%
// Solution
// True.

// %% [markdown]
// **Question 2: Memoization**
//
// Memoization is top-down and stores recursive results.
//
// - True
// - False

// %%
// Solution
// True.

// %% [markdown]
// **Question 3: Tabulation**
//
// Tabulation fills a table bottom-up in dependency order.
//
// - True
// - False

// %%
// Solution
// True.

// %% [markdown]
// **Question 4: Undo step**
//
// Backtracking often needs an undo step after exploring a choice.
//
// - True
// - False

// %%
// Solution
// True.

// %% [markdown]
// **Question 5: Unsafe pruning**
//
// A pruning rule is safe even if it can remove a valid solution branch.
//
// - True
// - False

// %%
// Solution
// False. Unsafe pruning makes the algorithm wrong.

// %% [markdown]
// ## Coding Questions
//
// **Question 6: Memoized stairs**
//
// A person can climb 1 or 2 stairs at a time. Write a memoized method that counts ways to climb `n` stairs.

// %%
using System;
using System.Collections.Generic;

int n = 5;

// Your code starts here.


// Your code ends here.

// %% [markdown]
// **Question 7: Tabulated stairs**
//
// Solve the same stairs problem with a bottom-up table.

// %%
using System;

int n = 5;

// Your code starts here.


// Your code ends here.

// %% [markdown]
// **Question 8: Minimum coins**
//
// Use tabulation to compute the fewest coins needed for a target amount.

// %%
using System;

int[] coins = { 1, 5, 10 };
int target = 18;

// Your code starts here.


// Your code ends here.

// %% [markdown]
// **Question 9: Generate subsets**
//
// Use backtracking to print all subsets of `{1, 2, 3}`.

// %%
using System;
using System.Collections.Generic;

int[] values = { 1, 2, 3 };

// Your code starts here.


// Your code ends here.

// %% [markdown]
// **Question 10: Pruned subset search**
//
// Write subset-sum search with a pruning condition for nonnegative values.

// %%
using System;

int[] values = { 4, 6, 9, 11 };
int target = 15;

// Your code starts here.


// Your code ends here.
