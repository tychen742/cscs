// %% [markdown]
// # Preview
//
// - Use these questions before class to check your familiarity with the chapter glossary and core terms.
// - Sign in from the account menu before you start answering the questions.
// - Multiple submissions are allowed if you want more practice.

// %% [markdown]
// ## Multiple Choice
//
// **1.** What are overlapping subproblems?
//
// a) Smaller problems that appear repeatedly
// b) Files with the same name
// c) Values that cannot be compared
// d) Loops that never run
//
// **2.** What does memoization store?
//
// a) Results of subproblems
// b) Console colors
// c) Git commits
// d) Source filenames only
//
// **3.** What does tabulation usually use?
//
// a) A bottom-up table
// b) A random search only
// c) A missing base case
// d) A stack trace as output
//
// **4.** What is the backtracking rhythm?
//
// a) Choose, explore, undo
// b) Sort, hash, delete
// c) Compile, ignore, repeat
// d) Print, pause, crash
//
// **5.** What is pruning?
//
// a) Skipping branches that cannot help
// b) Adding every possible branch
// c) Removing all base cases
// d) Replacing recursion with comments

// %% [markdown]
// ```{rubric} Footnotes
// ```
