// %% [markdown]
// # Lab
//
// - Use this lab to practice dynamic programming and backtracking in runnable C# code.
// - Sign in from the account menu before you start working on the lab.
// - Launch Live Code (the rocket) to write and run code in the coding cells.

// %% [markdown]
// ## 1. Count Naive Fibonacci Calls
//
// Write naive recursive Fibonacci and count calls.

// %%
using System;

int n = 8;
int calls = 0;

// Your code starts here.


// Your code ends here.

// %% [markdown]
// ## 2. Add Memoization
//
// Use a dictionary to cache Fibonacci results.

// %%
using System;
using System.Collections.Generic;

int n = 30;
var cache = new Dictionary<int, int>();

// Your code starts here.


// Your code ends here.

// %% [markdown]
// ## 3. Tabulate Coin Change
//
// Build a table for the fewest coins needed for a target amount.

// %%
using System;

int[] coins = { 1, 3, 4 };
int target = 6;

// Your code starts here.


// Your code ends here.

// %% [markdown]
// ## 4. Backtracking Subset Sum
//
// Search for a subset that reaches a target.

// %%
using System;

int[] values = { 3, 7, 10, 12 };
int target = 15;

// Your code starts here.


// Your code ends here.

// %% [markdown]
// ## 5. Add a Pruning Rule
//
// Add a pruning rule to stop exploring when the remaining target becomes negative.

// %%
using System;

int[] values = { 2, 4, 6, 9 };
int target = 8;

// Your code starts here.


// Your code ends here.

// %% [markdown]
// ## Project Connection
//
// Identify one project feature that has repeated subproblems or a decision search space. State whether DP or backtracking seems more natural and why.
