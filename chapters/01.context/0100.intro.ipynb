// %% [markdown]
// # Introduction

// %% [markdown]
// <h2> C#, .NET, and VS Code </h2>

// %% [markdown]
// Albeit the overall popularity of JavaScript and Python, Java and Microsoft .NET languages
// remain as strong general-purpose languages. Microsoft has, in recent years, made C# a
// central language for their fast-evolving, open-sourced, and cross-platform .NET ecosystem.
// C# is general-purpose, high-level, multiple-paradigm, and is gaining market share as a popular
// programming language [2] [3]. Specifically, C# is widely used in areas such as building
// cross-platform applications, web services, and game development. In addition,
// the Visual Studio Code (VS Code) editor, powered by plenty of extensions, has made the editor
// a very powerful tool for coding and programming and worth learning.
//
// As a general programming language, C# has been used in creating interactive websites,
// mobile apps, video games, augmented reality (AR) & virtual reality (VR), desktop
// applications, and back-end services. For example, the mobile game Pokemon Go is built
// with the Unity game engine and the Stack Overflow website is built with ASP.NET, both
// frameworks use C# as their programming language. In general, in terms of job market,
// C# and .NET are especially used by large enterprises.
//
// :::{figure} ../../images/stackoverflow_2023_pop_tech.jpg
// :alt: Popular programming languages used by professional developers, StackOverflow
// : developer annual survey 2023
// :scale: 60%
// Popular Programming Languages (StackOverflow Developer Annual Survey 2023 [4] )
// :::

// %%
#r "nuget: Microsoft.Data.Analysis"
#r "nuget: Plotly.NET"
#r "nuget: Plotly.NET.Interactive"

// %%
using System.IO;
using Microsoft.Data.Analysis;
using System.IO;
using System.Linq;
using Microsoft.Data.Analysis;
using Plotly.NET;
using Plotly.NET.Interactive;
using Plotly.NET.LayoutObjects;

var csvPath = "/Users/tcn85/workspace/cscs/data/survey_results_public-2025.csv";
var colCount = File.ReadLines(csvPath).First().Split(',').Length;
var stringTypes = new Type[colCount];
for (int i = 0; i < colCount; i++) stringTypes[i] = typeof(string);
var df = DataFrame.LoadCsv(csvPath, dataTypes: stringTypes);

var langCol = df["LanguageHaveWorkedWith"] as StringDataFrameColumn;
var counts = new Dictionary<string, int>();
int total = 0;
foreach (var val in langCol)
{
if (val == null) continue;
total++;
foreach (var lang in val.Split(';'))
{
var l = lang.Trim();
if (!string.IsNullOrEmpty(l))
counts[l] = counts.GetValueOrDefault(l, 0) + 1;
}
}

var top10 = counts.OrderByDescending(kv => kv.Value).Take(10).ToList();
var langs = top10.Select(kv => kv.Key).ToArray();
var pcts = top10.Select(kv => Math.Round(100.0 * kv.Value / total, 1)).ToArray();

Chart2D.Chart.Bar<double, string, string, string, string>(
values: pcts,
Keys: langs,
Name: "% Used"
)
.WithLayout(Layout.init<string>(
Width: 800, Height: 450,
Title: Title.init("Top 10 Technologies - Stack Overflow Survey 2025", X: 0.5, Y: 0.95),
Margin: Margin.init<int, int, int, int, int, int>(Top: 60, Right: 30, Bottom: 50, Left: 120)
))
.WithXAxis(LinearAxis.init<string, string, string, string, string, string, string, string>(
Title: Title.init("% of Respondents")
))
.WithYAxis(LinearAxis.init<string, string, string, string, string, string, string, string>(
Title: Title.init("Technology")
))
.Display();
// Out:
// <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Data.Analysis, 0.23.0</span></li><li><span>Plotly.NET, 5.1.0</span></li><li><span>Plotly.NET.Interactive, 5.0.0</span></li></ul></div></div>
// <div><div id="a734277d-9bd3-49b8-98eb-0df0beaed408"><!-- Plotly chart will be drawn inside this DIV --></div><script type="text/javascript">
// var renderPlotly_a734277d9bd349b898eb0df0beaed408 = function() {
//     var fsharpPlotlyRequire = requirejs.config({context:'fsharp-plotly',paths:{plotly:'https://cdn.plot.ly/plotly-2.27.1.min'}}) || require;
//     fsharpPlotlyRequire(['plotly'], function(Plotly) {
//         var data = [{"type":"bar","name":"% Used","x":[42.7,40.0,37.9,37.4,35.6,31.5,28.2,19.0,18.0,15.2],"y":["JavaScript","HTML/CSS","SQL","Python","NA","Bash/Shell (all shells)","TypeScript","Java","C#","C++"],"orientation":"h","marker":{"pattern":{}}}];
// ...

// %% [markdown]
// Also, according to [TIOBE Index](https://www.tiobe.com/tiobe-index/), C# is one of the most popular languages according to the number of [search engine hits](https://www.tiobe.com/tiobe-index/programminglanguages_definition/).

// %%
#r "nuget: HtmlAgilityPack"
#r "nuget: Plotly.NET"
#r "nuget: Plotly.NET.Interactive"
// Out:
// <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>HtmlAgilityPack, 1.12.4</span></li><li><span>Plotly.NET, 5.1.0</span></li><li><span>Plotly.NET.Interactive, 5.0.0</span></li></ul></div></div>

// %%
using System.Reflection;
using System.Runtime.CompilerServices;
using HtmlAgilityPack;
using Plotly.NET;
using Plotly.NET.Interactive;
using Plotly.NET.LayoutObjects;

var web = new HtmlWeb();
var doc = web.Load("https://www.tiobe.com/tiobe-index/");

var rows = doc.DocumentNode.SelectNodes("//table[contains(@id,'top20')]//tr");

var languages = new List<string>();
var ratings = new List<double>();

foreach (var row in rows.Skip(1))
{
    var cells = row.SelectNodes("td");
    if (cells != null && cells.Count >= 6)
    {
        languages.Add(cells[4].InnerText.Trim());
        if (double.TryParse(cells[5].InnerText.Replace("%", "").Trim(), out double rating))
            ratings.Add(rating);
    }
}

var top10Languages = languages.Take(10).ToArray();
var top10Ratings = ratings.Take(10).ToArray();

var chart = Chart2D.Chart.Bar<double, string, string, string, string>(
    values: top10Ratings,
    Keys: top10Languages,
    Name: "TIOBE Index"
)
.WithTitle("TIOBE Programming Community Index")
.WithLayout(Layout.init<string>(
    Width: 800, 
    Height: 450, 
    Title: Title.init("TIOBE Programming Community Index", X: 0.5, Y: 0.95),
    Margin: Margin.init<int, int, int, int, int, int>(Top: 60, Right: 20, Bottom: 50, Left: 120)
))
.WithXAxis(LinearAxis.init<string, string, string, string, string, string, string, string>(
    Title: Title.init("Rating (%)")
))
.WithYAxis(LinearAxis.init<string, string, string, string, string, string, string, string>(
    Title: Title.init("Language")
));
// chart.Show();
chart.Display();
// Out:
// <div><div id="784a86d2-2d15-488d-b646-7b67799038fd"><!-- Plotly chart will be drawn inside this DIV --></div><script type="text/javascript">
// var renderPlotly_784a86d22d15488db6467b67799038fd = function() {
//     var fsharpPlotlyRequire = requirejs.config({context:'fsharp-plotly',paths:{plotly:'https://cdn.plot.ly/plotly-2.27.1.min'}}) || require;
//     fsharpPlotlyRequire(['plotly'], function(Plotly) {
//         var data = [{"type":"bar","name":"TIOBE Index","x":[21.25,11.55,8.18,7.99,6.36,3.45,2.5,2.0,1.88,1.8],"y":["Python","C","C++","Java","C#","JavaScript","Visual Basic","SQL","R","Delphi/Object Pascal"],"orientation":"h","marker":{"pattern":{}}}];
// ...

// %% [markdown]
// [2] According to TIOBE index, C# is one of the most-searched programming languages. <https://www.tiobe.com/tiobe-index/>
//
// [3] The Stack Overflow Annual Survey 2023 shows that 29.16% of professional developers use C#, which is close to Java.
//
// [4] Popular programming languages according to the Stack Overflow Annual Developer Survey 2023. <https://survey.stackoverflow.co/2023/#most-popular-technologies-language-prof>
