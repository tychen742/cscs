# %% [markdown]
# ```{index} file
# ```
#
# (files)=
#
# # Files

# %% [markdown]
# <!-- chapter-intro -->
# This chapter introduces the core ideas of **Files** and prepares you for the sections that follow.

# %% [markdown]
# ```{tableofcontents}
# ```
