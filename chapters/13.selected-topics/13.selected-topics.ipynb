# %% [markdown]
# ```{index} selected topics type; data structure
# ```
#
# (selected-topics)=
#
# # Selected Topics
#
# ```{toctree}
# :maxdepth: 2
#
# 1301.testing
# 1302.recursion
# 1303.lab-selected-topics
# ```
#
# % 1303.searching
#
# % 1304.sorting
