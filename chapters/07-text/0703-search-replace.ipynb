// %% [markdown]
// # Search and Replace
//
// Search/replace is useful for cleanup and normalization pipelines.
//
// ## Finding text
//
// ```csharp
// string message = "error: invalid input";
//
// bool hasError = message.Contains("error", StringComparison.OrdinalIgnoreCase);
// int at = message.IndexOf("invalid", StringComparison.OrdinalIgnoreCase);
// ```
//
// Use `StringComparison.OrdinalIgnoreCase` for consistent case-insensitive checks.
//
// ## Replacing text
//
// ```csharp
// string raw = "Name: Alice\tScore: 98";
// string cleaned = raw.Replace("\t", " ").Replace("  ", " ");
// ```
//
// For repeated whitespace cleanup, loop until stable or use regex later in advanced courses.
//
// ## Safe replacement strategy
//
// 1. preserve original text
// 2. create cleaned copy
// 3. validate cleaned output
// 4. write output to new file first
//
// ```csharp
// string original = line;
// string updated = original.Replace("N/A", "0");
// ```
//
// ## Mini practice
//
// 1. Convert all semicolons to commas in a file.
// 2. Replace `"N/A"` with `"0"` in numeric columns.
// 3. Count how many lines changed.
