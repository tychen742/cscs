# %% [markdown]
# ```{index} collections, data collections
# ```
#
# (collections)=
#
# # Data Collections
#
# Arrays have fixed sizes. When the amount of data is unknown or changes while the program runs, C# provides dynamic collection types. This chapter introduces `List<T>` and `Dictionary<TKey, TValue>`, two of the most widely used collections.
#
# - **List**: A `List<T>` stores an ordered sequence that can grow or shrink.
# - **Dictionary**: A `Dictionary<TKey, TValue>` maps keys to values for fast lookup.
# - **Generics**: Generic type parameters keep collections type-safe while making them reusable.
# - **Access pattern**: Choosing a collection depends on whether you need order, lookup by key, insertion, removal, or traversal.
#
# Data collections let programs handle real data sizes and changing workloads without manually managing every storage detail.

# %% [markdown]
# <h2>Chapter Video</h2>
#
# ```{eval-rst}
# .. youtube:: 4Mi4OuSMo4A
#    :width: 560
#    :height: 315
# ```
#
# > *[C# Collections Tutorial: Working with List, Hashset, Dictionary, and More!](https://youtube.com/watch?v=4Mi4OuSMo4A)* by Coderversity.
# >
# > This video remains hosted on YouTube and is the property of its original creator or rightsholder; it is embedded here via YouTube's official player for educational reference only.

# %% [markdown]
# <h2>Learning Objectives</h2>
#
# By the end of this chapter, you will be able to:
# 1. Create and populate `List<T>` values using common list operations
# 2. Use `Dictionary<TKey, TValue>` to store and retrieve key-value pairs
# 3. Iterate over collections with `foreach` loops
# 4. Explain how generics make collections type-safe
# 5. Choose between arrays, lists, and dictionaries for common data tasks

# %% [markdown]
# <h2>Chapter Flow</h2>
#
# - {doc}`8.1. Choosing Data Collections <0801-collections>`
# - {doc}`8.2. Lists <0802-list>`
# - {doc}`8.3. Dictionaries <0803-dictionary>`

# %% [markdown]
# <h2>Glossary</h2>
#
# | # | Term | Explanation |
# |---:|---|---|
# | 1 | Collection | An object that stores multiple values and provides operations for working with them. |
# | 2 | Generic type | A type written with a type parameter, such as `List<T>`. |
# | 3 | Type parameter | A placeholder for the element type a generic collection stores. |
# | 4 | List | A resizable ordered collection accessed by index. |
# | 5 | Dictionary | A collection that maps keys to values. |
# | 6 | Key | A lookup value used to find an associated dictionary value. |
# | 7 | Value | The data associated with a dictionary key. |
# | 8 | Add | An operation that inserts a new item into a collection. |
# | 9 | Remove | An operation that deletes an item from a collection. |
# | 10 | Contains | A membership test that checks whether a collection has an item or key. |
# | 11 | Count | The number of items currently stored in a collection. |
# | 12 | Foreach loop | A loop that visits each item in a collection. |
# | 13 | Lookup | Retrieving a value by index or key. |
# | 14 | Access pattern | The way code most often reads, writes, searches, or traverses data. |
