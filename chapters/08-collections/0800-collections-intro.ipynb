# %% [markdown]
# ```{index} collections collections
# ```
#
# (collections)=
#
# # Collections

# %% [markdown]
# <!-- chapter-intro -->
# This chapter introduces the core ideas of **Collections** and prepares you for the sections that follow.

# %% [markdown]
# ```{tableofcontents}
# ```
