# %% [markdown]
# (defining-own-functions)=
#
# # Methods

# %% [markdown]
# <!-- chapter-intro -->
# This chapter introduces the core ideas of **Methods** and prepares you for the sections that follow.

# %% [markdown]
# ```{tableofcontents}
# ```
