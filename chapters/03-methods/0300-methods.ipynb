# %% [markdown]
# (defining-own-functions)=
#
# # Methods
#
# Long programs become unmanageable when all code lives in one place. Methods let you name a block of code, give it inputs, return a result, and reuse the same logic from multiple places.
#
# - **Method definition**: A method packages a named task so the program can call it when needed.
# - **Method signature**: The method name, parameters, and return type communicate how callers should use it.
# - **Parameters**: Parameters let one method work with different input values.
# - **Return values**: A value-returning method computes a result that other code can store or combine.
#
# Methods are the first major step from writing a script toward designing a program. They make code easier to read, test, debug, and extend.

# %% [markdown]
# <h2>Chapter Video</h2>
#
# ```{eval-rst}
# .. youtube:: IPpEefuFiVM
#    :width: 560
#    :height: 315
# ```
#
# > *[C# methods 📞](https://youtube.com/watch?v=IPpEefuFiVM)* by Bro Code.
# >
# > This video remains hosted on YouTube and is the property of its original creator or rightsholder; it is embedded here via YouTube's official player for educational reference only.

# %% [markdown]
# <h2>Learning Objectives</h2>
#
# By the end of this chapter, you will be able to:
# 1. Define methods with clear names, parameters, and return types
# 2. Call methods and use their return values in larger expressions
# 3. Design method signatures that communicate intent clearly
# 4. Distinguish between `void` methods and value-returning methods
# 5. Use methods to remove repetition and organize program logic

# %% [markdown]
# <h2>Chapter Flow</h2>
#
# ```{tableofcontents}
# ```

# %% [markdown]
# <h2>Glossary</h2>
#
# | # | Term | Explanation |
# |---:|---|---|
# | 1 | Method | A named block of code that performs a task and can be called from elsewhere. |
# | 2 | Method call | An instruction that runs a method. |
# | 3 | Parameter | A named input listed in a method definition. |
# | 4 | Argument | A value supplied to a parameter during a method call. |
# | 5 | Return type | The type of value a method sends back to its caller. |
# | 6 | Return value | The actual value produced by a value-returning method. |
# | 7 | Void method | A method that performs an action but does not return a value. |
# | 8 | Signature | The method name together with its parameter list. |
# | 9 | Scope | The region of code where a name can be used. |
# | 10 | Local variable | A variable declared inside a method or block. |
# | 11 | Helper method | A smaller method used to organize part of a larger task. |
# | 12 | Refactoring | Changing code structure without changing its intended behavior. |
