# %% [markdown]
# ```{index} class type; user defined object
# ```
#
# (classes)=
#
# # Classes
#
# ```{toctree}
# :maxdepth: 2
#
# 1001.intro-class
# 1002.class-examples
# 1003.rational
# 1004.structs
# 1005.lab-classes
# 1006.review-classes
# ```
