# %% [markdown]
# # Homework: Generics, Nullability & Async

# %% [markdown]
# ## Concept Questions
#
# 1. What is the difference between `?.` and `??`? Can they be combined?
# 2. What problem do generics solve? Why is `List<T>` better than `ArrayList`?
# 3. What does a `where T : IComparable<T>` constraint enforce, and why is it needed?
# 4. What does `await` do inside an `async` method? Does the calling thread block?
# 5. Why should you almost never write `async void` (except for event handlers)?

# %% [markdown]
# ## True / False
#
# 1. `x?.Foo` throws a `NullReferenceException` if `x` is null. ___
# 2. `int?` can hold `null`; plain `int` cannot. ___
# 3. A generic method `Max<T>` with no constraints can call `a.CompareTo(b)` on type parameter `T`. ___
# 4. `await` suspends the current method until the awaited `Task` completes, freeing the thread in the meantime. ___

# %% [markdown]
# ## Short Answer
#
# 1. Rewrite safely: `if (a != null) return a.Name;` (using null-conditional and coalescing).
# 2. Write the signature and implementation of a generic `static void Swap<T>(ref T a, ref T b)` method.
# 3. Convert `string text = File.ReadAllText(path)` to its async equivalent inside an `async Task` method.
