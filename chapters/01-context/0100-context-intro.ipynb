// %% [markdown]
// # Introduction

// %% [markdown]
// <!-- chapter-intro -->
// This chapter introduces the core ideas of **Introduction** and prepares you for the sections that follow.

// %% [markdown]
// ```{tableofcontents}
// ```
