# %% [markdown]
# (oop)=
#
# # OOP

# %% [markdown]
# <!-- chapter-intro -->
# This chapter introduces the core ideas of **Object-Oriented** and prepares you for the sections that follow.

# %% [markdown]
# ```{tableofcontents}
# ```
