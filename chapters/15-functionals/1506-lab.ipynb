// %% [markdown]
// # Lab: Selected Topics
//
// Apply recursion, lambdas, LINQ, pattern matching, and tuples in a set of focused exercises.

// %% [markdown]
// ## Part 1: Recursion
//
// Implement the following methods **recursively** (no loops allowed).
//
// **1a.** `int SumList(List<int> list, int index)` — return the sum of all elements starting at `index`.
//
// **1b.** `bool IsPalindrome(string s)` — return `true` if `s` reads the same forwards and backwards.
// - `IsPalindrome("racecar")` → `true`
// - `IsPalindrome("hello")` → `false`
//
// **1c.** `int CountOccurrences(string s, char c)` — count how many times `c` appears in `s`.

// %%
// Starter code — implement the bodies

static int SumList(List<int> list, int index)
{
    // TODO
    throw new NotImplementedException();
}

static bool IsPalindrome(string s)
{
    // TODO
    throw new NotImplementedException();
}

static int CountOccurrences(string s, char c)
{
    // TODO
    throw new NotImplementedException();
}

// %% [markdown]
// ## Part 2: Lambdas and LINQ
//
// Use the following dataset for all tasks:
//
// ```csharp
// record Product(string Name, string Category, double Price);
// ```

// %%
record Product(string Name, string Category, double Price);

var products = new List<Product>
{
    new("Laptop",     "Electronics", 999.99),
    new("Phone",      "Electronics", 699.00),
    new("Headphones", "Electronics", 149.99),
    new("Desk",       "Furniture",   349.00),
    new("Chair",      "Furniture",   199.00),
    new("Notebook",   "Stationery",   4.99),
    new("Pen",        "Stationery",   1.49),
};

// 2a. Names of Electronics under $500, sorted by price
// 2b. Average price per category
// 2c. Most expensive product overall
// 2d. Total revenue if all products sold once

// %% [markdown]
// ## Part 3: Pattern Matching
//
// **3a.** Write `string Fizzbuzz(int n)` using a switch expression with tuple patterns:
// - divisible by both 3 and 5 → `"FizzBuzz"`
// - divisible by 3 → `"Fizz"`
// - divisible by 5 → `"Buzz"`
// - otherwise → the number as a string
//
// Print the results for 1–20.

// %%
static string Fizzbuzz(int n) => (n % 3, n % 5) switch
{
    // TODO: fill in the arms
    _ => n.ToString()
};

for (int i = 1; i <= 20; i++)
    Console.Write(Fizzbuzz(i) + " ");

// %% [markdown]
// ## Part 4: Tuples
//
// **4a.** Write `(string Longest, string Shortest) LongShort(string[] words)` that returns the longest and shortest word.
//
// **4b.** Use LINQ on the `products` list to produce a `List<(string Category, double AvgPrice)>`,
// sorted by average price descending.

// %%
static (string Longest, string Shortest) LongShort(string[] words)
{
    // TODO
    throw new NotImplementedException();
}

// Test
var (longest, shortest) = LongShort(new[] { "cat", "elephant", "ox", "giraffe" });
Console.WriteLine($"Longest: {longest}, Shortest: {shortest}");
// Longest: elephant, Shortest: ox

// %% [markdown]
// ## Stretch Challenge
//
// Combine all techniques: given a text file of comma-separated records `Name,Score`,
// write a program that:
// 1. Reads the file into a `List<(string Name, int Score)>` (no class needed).
// 2. Uses LINQ to compute: top 3 scorers, average score, scores by grade bracket (A/B/C/D/F).
// 3. Uses a switch expression to assign each grade bracket.
// 4. Prints a formatted summary.
