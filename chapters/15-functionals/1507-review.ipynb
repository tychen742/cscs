// %% [markdown]
// # Chapter Review
//
// Review questions for Selected Topics.

// %% [markdown]
// ## Concept Questions
//
// 1. What are the two required parts of every recursive method? What happens if either is missing?
// 2. What is the difference between `Func<int, bool>` and `Action<int>`?
// 3. LINQ queries are *lazy*. What does that mean, and when does it matter?
// 4. What does the `_` discard mean in a switch expression arm?
// 5. When would you use a tuple instead of a class?
// 6. What is a closure? Give an example.

// %% [markdown]
// ## True / False
//
// 1. Every recursive method must have exactly one base case. ___
// 2. `Action<T>` returns a value; `Func<T>` does not. ___
// 3. `Where` modifies the original collection. ___
// 4. Named tuple fields are faster than unnamed fields at runtime. ___
// 5. Pattern matching in C# can test both type and value in the same arm. ___
// 6. `.ToList()` forces immediate evaluation of a LINQ query. ___

// %% [markdown]
// ## Short Answer
//
// 1. Trace the call stack for `Factorial(3)` showing each step.
// 2. Rewrite this loop as a LINQ chain:
//    ```csharp
//    var result = new List<int>();
//    foreach (int n in nums)
//        if (n > 0) result.Add(n * 2);
//    result.Sort();
//    ```
// 3. What does this switch expression return for input `'e'`?
//    ```csharp
//    char c = 'e';
//    string kind = c switch {
//        'a' or 'e' or 'i' or 'o' or 'u' => "vowel",
//        >= 'a' and <= 'z'               => "consonant",
//        _                               => "other"
//    };
//    ```
// 4. Write a one-liner using a lambda that finds the first even number greater than 10 in an array.
