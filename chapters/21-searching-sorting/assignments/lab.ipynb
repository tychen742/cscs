// %% [markdown]
// # Lab
//
// - Use this lab to practice searching, sorting, and algorithm comparison in runnable C# code.
// - Sign in from the account menu before you start working on the lab.
// - Launch Live Code (the rocket) to write and run code in the coding cells.

// %% [markdown]
// ## 1. Linear Search
//
// Write a method named `LinearSearch` that returns the first index of a target value or `-1`.

// %%
using System;

int[] values = { 8, 3, 5, 1, 9 };
int target = 5;

// Your code starts here.


// Your code ends here.

// %% [markdown]
// ## 2. Binary Search
//
// Write an iterative binary search method for a sorted array.

// %%
using System;

int[] values = { 1, 3, 5, 8, 9, 12 };
int target = 8;

// Your code starts here.


// Your code ends here.

// %% [markdown]
// ## 3. Selection Sort
//
// Implement selection sort and print the sorted result.

// %%
using System;

int[] values = { 8, 3, 5, 1, 9 };

// Your code starts here.


// Your code ends here.

// %% [markdown]
// ## 4. Insertion Sort Count
//
// Implement insertion sort and count comparisons.

// %%
using System;

int[] values = { 8, 3, 5, 1, 9 };
int comparisons = 0;

// Your code starts here.


// Your code ends here.

// %% [markdown]
// ## 5. Compare Recommendations
//
// Given a data scenario, print whether linear search, binary search, or dictionary lookup would be your first choice.

// %%
using System;

bool isSorted = true;
bool manyRepeatedLookups = true;
bool exactKeyLookup = false;

// Your code starts here.


// Your code ends here.

// %% [markdown]
// ## Project Connection
//
// Identify one place in your project where data must be searched or sorted. Name the data condition and the algorithm or library method you would use.
