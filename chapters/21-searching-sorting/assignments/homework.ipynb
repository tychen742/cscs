// %% [markdown]
// # Homework
//
// - Use these questions after class to check your understanding of the chapter concepts and coding skills.
// - Sign in from the account menu before you start working on the homework.
// - Complete all true/false and coding questions.

// %% [markdown]
// ## True or False
//
// **Question 1: Linear search**
//
// Linear search can be used on unsorted data.
//
// - True
// - False

// %%
// Solution
// True.

// %% [markdown]
// **Question 2: Binary search**
//
// Binary search requires sorted data.
//
// - True
// - False

// %%
// Solution
// True.

// %% [markdown]
// **Question 3: Selection sort**
//
// Selection sort repeatedly selects the smallest remaining value.
//
// - True
// - False

// %%
// Solution
// True.

// %% [markdown]
// **Question 4: Bubble sort**
//
// Bubble sort is usually the best practical sorting algorithm for large arrays.
//
// - True
// - False

// %%
// Solution
// False. Bubble sort is useful for learning, but not usually for large practical arrays.

// %% [markdown]
// **Question 5: Library sorting**
//
// In production C# code, `Array.Sort` or `List<T>.Sort` is usually preferred over hand-written elementary sorts.
//
// - True
// - False

// %%
// Solution
// True.

// %% [markdown]
// ## Coding Questions
//
// **Question 6: Linear search with strings**
//
// Write a linear search method for an array of strings.

// %%
using System;

string[] names = { "Ada", "Grace", "Katherine" };
string target = "Grace";

// Your code starts here.


// Your code ends here.

// %% [markdown]
// **Question 7: Count linear comparisons**
//
// Search for a missing integer and count how many comparisons occur.

// %%
using System;

int[] values = { 4, 8, 15, 16, 23, 42 };
int target = 99;

// Your code starts here.


// Your code ends here.

// %% [markdown]
// **Question 8: Binary search trace**
//
// Write binary search and print `low`, `high`, and `middle` during each iteration.

// %%
using System;

int[] values = { 2, 4, 6, 8, 10, 12, 14 };
int target = 12;

// Your code starts here.


// Your code ends here.

// %% [markdown]
// **Question 9: Bubble sort**
//
// Implement bubble sort for an integer array.

// %%
using System;

int[] values = { 6, 1, 5, 2, 4 };

// Your code starts here.


// Your code ends here.

// %% [markdown]
// **Question 10: Use a library sort**
//
// Use `Array.Sort` to sort an array, then use binary search to find one value.

// %%
using System;

int[] values = { 9, 4, 7, 1, 3 };
int target = 7;

// Your code starts here.


// Your code ends here.
