// %% [markdown]
// # Preview
//
// - Use these questions before class to check your familiarity with the chapter glossary and core terms.
// - Sign in from the account menu before you start answering the questions.
// - Multiple submissions are allowed if you want more practice.

// %% [markdown]
// ## Multiple Choice
//
// **1.** Which search works on unsorted data?
//
// a) Linear search
// b) Binary search only
// c) Merge sort
// d) Selection sort
//
// **2.** What precondition does binary search require?
//
// a) The data must be sorted
// b) The array must be empty
// c) The values must all be strings
// d) The loop must be recursive
//
// **3.** What does a swap operation do?
//
// a) Exchanges values at two positions
// b) Deletes a value
// c) Opens a file
// d) Creates a dictionary key
//
// **4.** Which sort repeatedly selects the smallest remaining item?
//
// a) Selection sort
// b) Binary search
// c) Linear search
// d) Queue sort
//
// **5.** Which growth rate is usually associated with binary search?
//
// a) `O(log n)`
// b) `O(n^2)`
// c) `O(n!)`
// d) `O(1)` for every input

// %% [markdown]
// ```{rubric} Footnotes
// ```
