// %% [markdown]
// # Searching and Sorting
//
// This chapter compares algorithms for locating and ordering data, using correctness and complexity tools from Chapters 19 and 20.
//
// ```{tableofcontents}
// ```
