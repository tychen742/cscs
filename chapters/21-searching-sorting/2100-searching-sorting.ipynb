// %% [markdown]
// # Searching and Sorting
//
// Searching and sorting are classic algorithm families because they appear in nearly every computing domain. Searching locates data. Sorting puts data into an order that makes later work easier, including faster searching.
//
// - **Linear search**: Checks items one by one until the target is found or the input ends.
// - **Binary search**: Uses sorted order to discard half of the remaining search range at each step.
// - **Elementary sort**: A simple sorting algorithm, such as selection sort, insertion sort, or bubble sort, that is easy to trace but usually quadratic.
// - **Comparison count**: A useful operation count for algorithms that decide order by comparing values.

// %% [markdown]
// <h2>Learning Objectives</h2>
//
// By the end of this chapter, you will be able to:
//
// 1. Select linear search or binary search based on data conditions.
// 2. Trace linear search and binary search step by step.
// 3. Explain the swap operation used by array-based sorting algorithms.
// 4. Trace selection sort, insertion sort, and bubble sort on small arrays.
// 5. Compare searching and sorting algorithms using correctness tests, comparison counts, and growth rates.

// %% [markdown]
// <h2>Chapter Flow</h2>
//
// ```{tableofcontents}
// ```

// %% [markdown]
// <h2>Glossary</h2>
//
// ```{glossary}
// Linear search
//   A search algorithm that checks items sequentially.
//
// Binary search
//   A search algorithm for sorted data that repeatedly halves the remaining search range.
//
// Sorted order
//   An arrangement where values follow a chosen ordering rule.
//
// Swap
//   An operation that exchanges values at two positions.
//
// Selection sort
//   A sorting algorithm that repeatedly selects the smallest remaining value and moves it into place.
//
// Insertion sort
//   A sorting algorithm that grows a sorted prefix by inserting each new item into its correct position.
//
// Bubble sort
//   A sorting algorithm that repeatedly swaps adjacent out-of-order values.
// ```

// %% [markdown]
// <h2>Slides</h2>
//
// Slides for this chapter will be added after the notebook content stabilizes.
