// %% [markdown]
// # Chapter Review: Selected Topics

// %% [markdown]
// ## Concept Questions
//
// 1. What are the two required parts of every recursive method? What happens if either is missing?
// 2. What is the difference between `Func<int, bool>` and `Action<int>`?
// 3. LINQ queries are *lazy*. What does that mean, and when does it matter?
// 4. What is a closure? Give a code example showing a lambda that captures a local variable.
// 5. When would you choose `Select` over `Where`? Can they be chained?
// 6. What is the call-stack risk of recursion, and how do you mitigate it?

// %% [markdown]
// ## True / False
//
// 1. Every recursive method must have exactly one base case. ___
// 2. `Action<T>` returns a value; `Func<T>` does not. ___
// 3. `Where` modifies the original collection in place. ___
// 4. A lambda expression can capture a local variable from the method that defines it. ___
// 5. `.ToList()` forces immediate evaluation of a LINQ query. ___
// 6. Tail recursion is automatically optimized by the C# compiler. ___

// %% [markdown]
// ## Short Answer
//
// 1. Trace the call stack for `Factorial(4)` showing each recursive call and return value.
// 2. Rewrite this loop as a LINQ chain:
//    ```csharp
//    var result = new List<int>();
//    foreach (int n in nums)
//        if (n > 0) result.Add(n * 2);
//    result.Sort();
//    ```
// 3. Write a one-liner using a lambda that finds the **first** even number greater than 10 in an array.
// 4. What does `Aggregate` do? Write an expression using it to join a `List<string>` with commas.
