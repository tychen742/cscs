# %% [markdown]
# ```{index} file
# ```
#
# (files)=
#
# # Files & Paths
#
# ```{toctree}
# :maxdepth: 2
#
# 0701.stream-file
# 0702.file-write
# 0703.file-read
# 0704.paths
# 0705.lab-file
# 0706.review-files
# ```
