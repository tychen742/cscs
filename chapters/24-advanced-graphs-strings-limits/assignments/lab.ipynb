// %% [markdown]
// # Lab
//
// - Use this lab to practice advanced graph, string, and algorithm-selection ideas in runnable C# code.
// - Sign in from the account menu before you start working on the lab.
// - Launch Live Code (the rocket) to write and run code in the coding cells.

// %% [markdown]
// ## 1. BFS Order
//
// Implement BFS on a small graph and print visit order.

// %%
using System;
using System.Collections.Generic;

// Your code starts here.


// Your code ends here.

// %% [markdown]
// ## 2. DFS Reachability
//
// Implement recursive DFS that returns whether a target can be reached.

// %%
using System;
using System.Collections.Generic;

// Your code starts here.


// Your code ends here.

// %% [markdown]
// ## 3. Unweighted Path
//
// Use BFS predecessors to reconstruct a path.

// %%
using System;
using System.Collections.Generic;

// Your code starts here.


// Your code ends here.

// %% [markdown]
// ## 4. Direct String Match
//
// Write a direct string matching method that returns the first index of a pattern.

// %%
using System;

string text = "abracadabra";
string pattern = "cad";

// Your code starts here.


// Your code ends here.

// %% [markdown]
// ## 5. Growth Warning
//
// Print estimated work for `n`, `n^2`, and `2^n` for several input sizes.

// %%
using System;

int[] sizes = { 10, 20, 30 };

// Your code starts here.


// Your code ends here.

// %% [markdown]
// ## Project Connection
//
// Choose one algorithmic feature from your course project. State the input size, the likely growth rate, and whether exact computation remains practical.
