// %% [markdown]
// # Homework
//
// - Use these questions after class to check your understanding of the chapter concepts and coding skills.
// - Sign in from the account menu before you start working on the homework.
// - Complete all true/false and coding questions.

// %% [markdown]
// ## True or False
//
// **Question 1: BFS**
//
// BFS explores an unweighted graph in layers.
//
// - True
// - False

// %%
// Solution
// True.

// %% [markdown]
// **Question 2: DFS**
//
// DFS never needs a visited set when a graph has cycles.
//
// - True
// - False

// %%
// Solution
// False. Cycles can cause repeated visits without a visited set.

// %% [markdown]
// **Question 3: String matching**
//
// Direct string matching tries possible starting positions in the text.
//
// - True
// - False

// %%
// Solution
// True.

// %% [markdown]
// **Question 4: Prefix table**
//
// A prefix table stores reusable information about a pattern.
//
// - True
// - False

// %%
// Solution
// True.

// %% [markdown]
// **Question 5: Limits**
//
// An exponential exact algorithm can become impractical quickly as input size grows.
//
// - True
// - False

// %%
// Solution
// True.

// %% [markdown]
// ## Coding Questions
//
// **Question 6: BFS visited set**
//
// Write BFS for a graph with a cycle and use a visited set.

// %%
using System;
using System.Collections.Generic;

// Your code starts here.


// Your code ends here.

// %% [markdown]
// **Question 7: Count components**
//
// Count connected components in a small undirected graph.

// %%
using System;
using System.Collections.Generic;

// Your code starts here.


// Your code ends here.

// %% [markdown]
// **Question 8: Naive match count**
//
// Write direct string matching and count character comparisons.

// %%
using System;

string text = "aaaaab";
string pattern = "aaab";

// Your code starts here.


// Your code ends here.

// %% [markdown]
// **Question 9: Prefix table**
//
// Build a prefix table for a pattern and print it.

// %%
using System;

string pattern = "ababaca";

// Your code starts here.


// Your code ends here.

// %% [markdown]
// **Question 10: Algorithm recommendation**
//
// Given a scenario string, recommend exact, approximate, or heuristic reasoning.

// %%
using System;

string scenario = "need a good route quickly for a large input";

// Your code starts here.


// Your code ends here.
