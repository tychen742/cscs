// %% [markdown]
// # Preview
//
// - Use these questions before class to check your familiarity with the chapter glossary and core terms.
// - Sign in from the account menu before you start answering the questions.
// - Multiple submissions are allowed if you want more practice.

// %% [markdown]
// ## Multiple Choice
//
// **1.** Which data structure does BFS use most directly?
//
// a) Queue
// b) Stack only
// c) Sorted array only
// d) Hash table only
//
// **2.** Which traversal follows one path before backing up?
//
// a) DFS
// b) BFS
// c) Bubble sort
// d) Tabulation
//
// **3.** What does string matching search for?
//
// a) A pattern inside text
// b) A minimum spanning tree
// c) A heap parent
// d) A nullable warning
//
// **4.** What does a prefix table help reuse?
//
// a) Information about matched pattern prefixes
// b) Database rows
// c) Console input
// d) Random numbers
//
// **5.** What is an approximation useful for?
//
// a) Getting a good enough answer when exact search is too expensive
// b) Making every algorithm exact
// c) Removing input constraints
// d) Avoiding all tests

// %% [markdown]
// ```{rubric} Footnotes
// ```
