// %% [markdown]
// # Advanced Graph Algorithms, Strings, and Computational Limits
//
// This chapter connects graph traversal, shortest paths, string matching, and the practical limits of efficient computation.
//
// ```{tableofcontents}
// ```
