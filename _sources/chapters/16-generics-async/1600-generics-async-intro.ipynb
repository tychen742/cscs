# %% [markdown]
# # Generics, Nullability & Async
#
# <!-- chapter-intro -->
#
# Modern C# programs need to stay type-safe, avoid null-reference bugs, and stay responsive while waiting on
# slow operations. This chapter covers three independent but equally essential tools: generics, nullable
# reference types, and async/await.

# %% [markdown]
# <h2>Why this chapter matters</h2>
#
# - **Generics** — explain the `<T>` you have been using in `List<T>` and LINQ; writing generic methods and classes yourself reduces duplication
# - **Nullable reference types** — make null-handling explicit and safe; `?.`, `??`, `??=` are in every real codebase
# - **Async/await** — keep programs responsive while waiting for files, networks, or databases without writing complex threading code

# %% [markdown]
# <h2>Learning goals</h2>
#
# By the end of this chapter, you should be able to:
#
# - write and read generic methods and classes that use `<T>` and type constraints
# - handle null safely using `?.`, `??`, `??=`, and nullable annotations
# - call `async` methods using `await` and understand when asynchrony is appropriate

# %% [markdown]
# <h2>Intro video</h2>
#
# ```{eval-rst}
# .. youtube:: aNTDJ9bnRU4
#    :width: 560
#    :height: 315
# ```
#
# > *[C# generics ⁉️](https://youtube.com/watch?v=aNTDJ9bnRU4)* by Bro Code.
# >
# > This video remains hosted on YouTube and is the property of its original creator or rightsholder; it is embedded here via YouTube's official player for educational reference only.

# %% [markdown]
# <h2>Chapter flow</h2>
#
# ```{tableofcontents}
# ```
