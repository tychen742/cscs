# %% [markdown]
# # Index
#
# The following index collects all terms defined throughout the book.
#
# ```{raw} html
# <p><a href="../../genindex.html" class="reference external">&#8594; Open full index page</a></p>
# <iframe src="../../genindex.html" style="width:100%; height:80vh; border:1px solid #ccc; border-radius:4px;"></iframe>
# ```
